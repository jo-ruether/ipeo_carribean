# %% [markdown]
# # Calculating features

# %%
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input

import numpy as np
import pandas as pd
from os.path import join
import os
# Out:
# Using TensorFlow backend.

# %%
regions = ['borde_rural', 'borde_soacha', 'mixco_1_and_ebenezer', 'mixco_3']

# %%
region = 'dennery'
train_dir = join('..', '..', 'data', 'data2', region, 'roofs_train')
test_dir = join('..', '..', 'data', 'data2', region, 'roofs_test')
materials = {'concrete_cement':0, 'healthy_metal':1, 'incomplete':2, 'irregular_metal':3, 'other':4}

# %% [markdown]
# Use a pretrained network to compute features from the images, which are later classified. Import the model from the Kerase library and remove the top layer by setting `include_top=False`. The last layer is pooled such that we get outputs of size 1x2048 instead of 7x7x2048. The pooling method `'max'` is chosen empirically.

# %%
model = ResNet50(weights='imagenet', include_top=False, pooling='max')
model.summary()
# Out:
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/ipeo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 5s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 2 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 2 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 2 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1. Calculate features on the training data

# %% [markdown]
# The preprocessed data is stored in such a way, that every region has their own folder, that contains a subfolder defined as `train_dir` above. This folder again is subdivided by material. Images carry their `id` as filename.
#
# Traverse all images in their corresponding folders which indicate the material and use `model.predict()` to get the features.

# %%
def calculate_features_train(train_dir):
    
    # Initialize a dataframe for the features    
    columns = ['id', 'features', 'label']
    df_features = pd.DataFrame(columns=columns)
    
    data = []

    # Walk through all images
    for material in materials.keys():
        material_fp = join(train_dir, material)
        for root, dirs, files in os.walk(material_fp):
            for file in files:
                img_fp = join(material_fp, file)
                label = materials[material]
                id = file.split('.')[0]
                print(id, "labeled as", material, ":", label)

                # Pad if size is too small, preprocess
                img = image.load_img(img_fp, target_size=(224, 224))
                img_data = image.img_to_array(img)
                img_data = np.expand_dims(img_data, axis=0)
                img_data = preprocess_input(img_data)

                # Compute features 
                features = model.predict(img_data)
                features_np = np.array(features).flatten()

                data.append({'id': id ,
                             'features': features_np,
                             'label': label})
                #df_features = df_features.append({'id': id ,
                #                                  'features': resnet50_feature_np,
                #                                  'label': label}, ignore_index=True)
    
    df_features = pd.DataFrame(data)
    return df_features

# %% [markdown]
# The results are stored in a dataframe as shown below and saved to disk as a pickle file.

# %%
print(train_dir)
# Out:
# ../../data/data2/borde_soacha/roofs_train

# %%
features_train = calculate_features_train(train_dir)
# Out:
# 7a20f7ac labeled as concrete_cement : 0
# 7a38b298 labeled as concrete_cement : 0
# 7a3a662e labeled as concrete_cement : 0
# 7a3d7d28 labeled as concrete_cement : 0
# 7a397142 labeled as concrete_cement : 0
# 7a382b34 labeled as concrete_cement : 0
# 7a38f03c labeled as concrete_cement : 0
# 7a238a3a labeled as concrete_cement : 0
# 7a2888fa labeled as concrete_cement : 0
# 7a3709c0 labeled as concrete_cement : 0
# 7a1d5caa labeled as concrete_cement : 0
# 7a1d085e labeled as concrete_cement : 0
# 7a2eb22a labeled as concrete_cement : 0
# 7a23f1dc labeled as concrete_cement : 0
# 7a3c5e66 labeled as concrete_cement : 0
# 7a2ac9b2 labeled as concrete_cement : 0
# 7a2bc9de labeled as concrete_cement : 0
# 7a2ad164 labeled as concrete_cement : 0
# 7a2792a6 labeled as concrete_cement : 0
# 7a2eea10 labeled as concrete_cement : 0
# 7a372f54 labeled as concrete_cement : 0
# 7a2ae12c labeled as concrete_cement : 0
# 7a3b557a labeled as concrete_cement : 0
# 7a3b9904 labeled as concrete_cement : 0
# 7a1d64a2 labeled as concrete_cement : 0
# 7a37557e labeled as concrete_cement : 0
# 7a41801c labeled as concrete_cement : 0
# 7a352c2c labeled as concrete_cement : 0
# 7a2ec526 labeled as concrete_cement : 0
# 7a349c8a labeled as concrete_cement : 0
# 7a1ec4be labeled as concrete_cement : 0
# 7a3fc524 labeled as concrete_cement : 0
# 7a216426 labeled as concrete_cement : 0
# 7a2e9c40 labeled as concrete_cement : 0
# 7a1fc7a6 labeled as concrete_cement : 0
# 7a33aff0 labeled as concrete_cement : 0
# 7a38e358 labeled as concrete_cement : 0
# 7a23ca0e labeled as concrete_cement : 0
# 7a3d3214 labeled as concrete_cement : 0
# 7a39df38 labeled as concrete_cement : 0
# 7a42e3b2 labeled as concrete_cement : 0
# 7a1e6e06 labeled as concrete_cement : 0
# 7a38d7b4 labeled as concrete_cement : 0
# 7a41f678 labeled as concrete_cement : 0
# 7a1fd35e labeled as concrete_cement : 0
# 7a304dd8 labeled as concrete_cement : 0
# 7a3037c6 labeled as concrete_cement : 0
# 7a26f0a8 labeled as concrete_cement : 0
# 7a312f3c labeled as concrete_cement : 0
# 7a44cb6e labeled as concrete_cement : 0
# 7a39eb04 labeled as concrete_cement : 0
# 7a2c33a6 labeled as concrete_cement : 0
# 7a38f8fc labeled as concrete_cement : 0
# 7a393eca labeled as concrete_cement : 0
# 7a3d3b24 labeled as concrete_cement : 0
# 7a408d24 labeled as concrete_cement : 0
# 7a3c0af6 labeled as concrete_cement : 0
# 7a3ddb2e labeled as concrete_cement : 0
# 7a3f1606 labeled as concrete_cement : 0
# 7a277622 labeled as concrete_cement : 0
# 7a1cea0e labeled as concrete_cement : 0
# 7a3d3bf6 labeled as concrete_cement : 0
# 7a1d96ca labeled as concrete_cement : 0
# 7a3a3a82 labeled as concrete_cement : 0
# 7a29fafa labeled as concrete_cement : 0
# 7a1db43e labeled as concrete_cement : 0
# 7a2bbfde labeled as concrete_cement : 0
# 7a2f98c0 labeled as concrete_cement : 0
# 7a346f30 labeled as concrete_cement : 0
# 7a21cfce labeled as concrete_cement : 0
# 7a233670 labeled as concrete_cement : 0
# 7a1c66f6 labeled as concrete_cement : 0
# 7a4080a4 labeled as concrete_cement : 0
# 7a3c1d8e labeled as concrete_cement : 0
# 7a23d508 labeled as concrete_cement : 0
# 7a3758d0 labeled as concrete_cement : 0
# 7a2c8b8a labeled as concrete_cement : 0
# 7a27656a labeled as concrete_cement : 0
# 7a2ea83e labeled as concrete_cement : 0
# 7a3f0e36 labeled as concrete_cement : 0
# 7a1e9de0 labeled as concrete_cement : 0
# 7a2d5560 labeled as concrete_cement : 0
# 7a2d7b6c labeled as concrete_cement : 0
# 7a27a796 labeled as concrete_cement : 0
# 7a1e4bb0 labeled as concrete_cement : 0
# 7a2037d6 labeled as concrete_cement : 0
# 7a249ce0 labeled as concrete_cement : 0
# 7a3edcc2 labeled as concrete_cement : 0
# 7a20bdbe labeled as concrete_cement : 0
# 7a422238 labeled as concrete_cement : 0
# 7a3809a6 labeled as concrete_cement : 0
# 7a3c88fa labeled as concrete_cement : 0
# 7a205f4a labeled as concrete_cement : 0
# 7a22aeee labeled as concrete_cement : 0
# 7a3e8f42 labeled as concrete_cement : 0
# 7a2e2e68 labeled as concrete_cement : 0
# 7a2abcc4 labeled as concrete_cement : 0
# 7a33726a labeled as concrete_cement : 0
# 7a2076ba labeled as concrete_cement : 0
# 7a2beda6 labeled as concrete_cement : 0
# 7a36bd44 labeled as concrete_cement : 0
# 7a298a2a labeled as concrete_cement : 0
# 7a3f16d8 labeled as concrete_cement : 0
# 7a2992ae labeled as concrete_cement : 0
# 7a1e156e labeled as concrete_cement : 0
# 7a2d86fc labeled as concrete_cement : 0
# 7a44cf56 labeled as concrete_cement : 0
# 7a34f5b8 labeled as concrete_cement : 0
# 7a3c0bc8 labeled as concrete_cement : 0
# 7a3d6a5e labeled as concrete_cement : 0
# 7a22ef9e labeled as concrete_cement : 0
# 7a31642a labeled as concrete_cement : 0
# 7a2ef7b2 labeled as concrete_cement : 0
# 7a1d6434 labeled as concrete_cement : 0
# 7a2d1de8 labeled as concrete_cement : 0
# 7a31c532 labeled as concrete_cement : 0
# 7a3f290c labeled as concrete_cement : 0
# 7a43c69c labeled as concrete_cement : 0
# 7a3f0bb6 labeled as concrete_cement : 0
# 7a28074a labeled as concrete_cement : 0
# 7a1e1302 labeled as concrete_cement : 0
# 7a3fe9dc labeled as concrete_cement : 0
# 7a24936c labeled as concrete_cement : 0
# 7a3054e0 labeled as concrete_cement : 0
# 7a2b224a labeled as concrete_cement : 0
# 7a1dd0f4 labeled as concrete_cement : 0
# 7a364094 labeled as concrete_cement : 0
# 7a3b4f58 labeled as concrete_cement : 0
# 7a1fc594 labeled as concrete_cement : 0
# 7a220eb2 labeled as concrete_cement : 0
# 7a3f9c2a labeled as concrete_cement : 0
# 7a429006 labeled as concrete_cement : 0
# 7a204b86 labeled as concrete_cement : 0
# 7a440e40 labeled as concrete_cement : 0
# 7a2757f0 labeled as concrete_cement : 0
# 7a30dece labeled as concrete_cement : 0
# 7a1eb604 labeled as concrete_cement : 0
# 7a3fe752 labeled as concrete_cement : 0
# 7a1ec734 labeled as concrete_cement : 0
# 7a43a52c labeled as concrete_cement : 0
# 7a3934ca labeled as concrete_cement : 0
# 7a428d0e labeled as concrete_cement : 0
# 7a25ab4e labeled as concrete_cement : 0
# 7a1e499e labeled as concrete_cement : 0
# 7a36c96a labeled as concrete_cement : 0
# 7a2c3cac labeled as concrete_cement : 0
# 7a1e835a labeled as concrete_cement : 0
# 7a218d98 labeled as concrete_cement : 0
# 7a2ce9cc labeled as concrete_cement : 0
# 7a41f25e labeled as concrete_cement : 0
# 7a25ba58 labeled as concrete_cement : 0
# 7a3efe0a labeled as concrete_cement : 0
# 7a3fee96 labeled as concrete_cement : 0
# 7a4232dc labeled as concrete_cement : 0
# 7a2ecc9c labeled as concrete_cement : 0
# 7a29771a labeled as concrete_cement : 0
# 7a26ec0c labeled as concrete_cement : 0
# 7a3a0d50 labeled as concrete_cement : 0
# 7a1d6506 labeled as concrete_cement : 0
# 7a1e5984 labeled as concrete_cement : 0
# 7a30d2bc labeled as concrete_cement : 0
# 7a1e2b62 labeled as concrete_cement : 0
# 7a36393c labeled as concrete_cement : 0
# 7a301778 labeled as concrete_cement : 0
# 7a257e1c labeled as concrete_cement : 0
# 7a28667c labeled as concrete_cement : 0
# 7a3d49f2 labeled as concrete_cement : 0
# 7a388458 labeled as concrete_cement : 0
# 7a2d17b2 labeled as concrete_cement : 0
# 7a3c81ac labeled as concrete_cement : 0
# 7a2544f6 labeled as concrete_cement : 0
# 7a20fcc0 labeled as concrete_cement : 0
# 7a28c7e8 labeled as concrete_cement : 0
# 7a34b90e labeled as concrete_cement : 0
# 7a220886 labeled as concrete_cement : 0
# 7a3a450e labeled as concrete_cement : 0
# 7a369e5e labeled as concrete_cement : 0
# 7a2a1dc8 labeled as concrete_cement : 0
# 7a1feae2 labeled as concrete_cement : 0
# 7a1cfc10 labeled as concrete_cement : 0
# 7a37c964 labeled as concrete_cement : 0
# 7a3f9658 labeled as concrete_cement : 0
# 7a20771e labeled as concrete_cement : 0
# 7a2d8c10 labeled as concrete_cement : 0
# 7a43bda0 labeled as concrete_cement : 0
# 7a3c60dc labeled as concrete_cement : 0
# 7a29b680 labeled as concrete_cement : 0
# 7a37ae52 labeled as concrete_cement : 0
# 7a252066 labeled as concrete_cement : 0
# 7a3ede02 labeled as concrete_cement : 0
# 7a3664c0 labeled as concrete_cement : 0
# 7a343344 labeled as concrete_cement : 0
# 7a2cb2d6 labeled as concrete_cement : 0
# 7a324aa2 labeled as concrete_cement : 0
# 7a364abc labeled as concrete_cement : 0
# 7a2c188a labeled as concrete_cement : 0
# 7a3dee66 labeled as concrete_cement : 0
# 7a2e4a56 labeled as concrete_cement : 0
# 7a4094a4 labeled as concrete_cement : 0
# 7a21bdae labeled as concrete_cement : 0
# 7a393178 labeled as concrete_cement : 0
# 7a1edb2a labeled as concrete_cement : 0
# 7a41eb6a labeled as concrete_cement : 0
# 7a3a1e30 labeled as concrete_cement : 0
# 7a285196 labeled as concrete_cement : 0
# 7a1e9192 labeled as concrete_cement : 0
# 7a2bac6a labeled as concrete_cement : 0
# 7a449e5a labeled as concrete_cement : 0
# 7a239a66 labeled as concrete_cement : 0
# 7a1e7158 labeled as concrete_cement : 0
# 7a25838a labeled as concrete_cement : 0
# 7a2bb426 labeled as concrete_cement : 0
# 7a2abc10 labeled as concrete_cement : 0
# 7a24b78e labeled as concrete_cement : 0
# 7a1ca080 labeled as concrete_cement : 0
# 7a200b44 labeled as concrete_cement : 0
# 7a21ce8e labeled as concrete_cement : 0
# 7a2f63be labeled as concrete_cement : 0
# 7a4072d0 labeled as concrete_cement : 0
# 7a4097f6 labeled as concrete_cement : 0
# 7a1c7646 labeled as concrete_cement : 0
# 7a231956 labeled as concrete_cement : 0
# 7a2035ce labeled as concrete_cement : 0
# 7a310d72 labeled as concrete_cement : 0
# 7a285128 labeled as concrete_cement : 0
# 7a1cd0a0 labeled as concrete_cement : 0
# 7a40aa70 labeled as concrete_cement : 0
# 7a319440 labeled as concrete_cement : 0
# 7a36181c labeled as concrete_cement : 0
# 7a44a2ba labeled as concrete_cement : 0
# 7a29006e labeled as concrete_cement : 0
# 7a274de6 labeled as concrete_cement : 0
# 7a2042a8 labeled as concrete_cement : 0
# 7a2b351e labeled as concrete_cement : 0
# 7a43c9da labeled as concrete_cement : 0
# 7a25fcb6 labeled as concrete_cement : 0
# 7a2179ca labeled as concrete_cement : 0
# 7a3cc0cc labeled as concrete_cement : 0
# 7a205c0c labeled as concrete_cement : 0
# 7a2f0f9a labeled as concrete_cement : 0
# 7a251b5c labeled as concrete_cement : 0
# 7a1ddaae labeled as concrete_cement : 0
# 7a35a684 labeled as concrete_cement : 0
# 7a35c574 labeled as concrete_cement : 0
# 7a2bd0fa labeled as concrete_cement : 0
# 7a2fd63c labeled as concrete_cement : 0
# 7a31e008 labeled as concrete_cement : 0
# 7a2562e2 labeled as concrete_cement : 0
# 7a2a18dc labeled as concrete_cement : 0
# 7a3aa062 labeled as concrete_cement : 0
# 7a333340 labeled as concrete_cement : 0
# 7a271736 labeled as concrete_cement : 0
# 7a1cdf3c labeled as concrete_cement : 0
# 7a2f5e50 labeled as concrete_cement : 0
# 7a2dd30a labeled as concrete_cement : 0
# 7a40daa4 labeled as concrete_cement : 0
# 7a2d31f2 labeled as concrete_cement : 0
# 7a3951f8 labeled as concrete_cement : 0
# 7a3e654e labeled as concrete_cement : 0
# 7a204d2a labeled as concrete_cement : 0
# 7a2fec80 labeled as concrete_cement : 0
# 7a335974 labeled as concrete_cement : 0
# 7a370b6e labeled as concrete_cement : 0
# 7a3d4434 labeled as concrete_cement : 0
# 7a2e3084 labeled as concrete_cement : 0
# 7a44b480 labeled as concrete_cement : 0
# 7a2ee24a labeled as concrete_cement : 0
# 7a24a384 labeled as concrete_cement : 0
# 7a2e51f4 labeled as concrete_cement : 0
# 7a36160a labeled as concrete_cement : 0
# 7a3e2354 labeled as concrete_cement : 0
# 7a25be90 labeled as concrete_cement : 0
# 7a2d1532 labeled as concrete_cement : 0
# 7a29e736 labeled as concrete_cement : 0
# 7a22ed8c labeled as concrete_cement : 0
# 7a294182 labeled as concrete_cement : 0
# 7a43b350 labeled as concrete_cement : 0
# 7a32ea8e labeled as concrete_cement : 0
# 7a2c4058 labeled as concrete_cement : 0
# 7a36a5a2 labeled as healthy_metal : 1
# 7a31acb4 labeled as healthy_metal : 1
# 7a34a004 labeled as healthy_metal : 1
# 7a26b9f8 labeled as healthy_metal : 1
# 7a1f58ac labeled as healthy_metal : 1
# 7a21a47c labeled as healthy_metal : 1
# 7a208c86 labeled as healthy_metal : 1
# 7a38c238 labeled as healthy_metal : 1
# 7a28301c labeled as healthy_metal : 1
# 7a41e39a labeled as healthy_metal : 1
# 7a2c9d96 labeled as healthy_metal : 1
# 7a36a6d8 labeled as healthy_metal : 1
# 7a1ff258 labeled as healthy_metal : 1
# 7a367cc6 labeled as healthy_metal : 1
# 7a3c31d4 labeled as healthy_metal : 1
# 7a2b367c labeled as healthy_metal : 1
# 7a2d0560 labeled as healthy_metal : 1
# 7a21ff30 labeled as healthy_metal : 1
# 7a39f13a labeled as healthy_metal : 1
# 7a4335b0 labeled as healthy_metal : 1
# 7a23d90e labeled as healthy_metal : 1
# 7a30be62 labeled as healthy_metal : 1
# 7a2d570e labeled as healthy_metal : 1
# 7a1fe790 labeled as healthy_metal : 1
# 7a3e4424 labeled as healthy_metal : 1
# 7a3b8c02 labeled as healthy_metal : 1
# 7a40f872 labeled as healthy_metal : 1
# 7a234124 labeled as healthy_metal : 1
# 7a3fc6d2 labeled as healthy_metal : 1
# 7a1f5d8e labeled as healthy_metal : 1
# 7a296bda labeled as healthy_metal : 1
# 7a2d07e0 labeled as healthy_metal : 1
# 7a33fa14 labeled as healthy_metal : 1
# 7a3dc986 labeled as healthy_metal : 1
# 7a44a030 labeled as healthy_metal : 1
# 7a3867e8 labeled as healthy_metal : 1
# 7a3372ce labeled as healthy_metal : 1
# 7a229170 labeled as healthy_metal : 1
# 7a25b986 labeled as healthy_metal : 1
# 7a3665f6 labeled as healthy_metal : 1
# 7a25da56 labeled as healthy_metal : 1
# 7a401efc labeled as healthy_metal : 1
# 7a31e4ea labeled as healthy_metal : 1
# 7a3006f2 labeled as healthy_metal : 1
# 7a3eb800 labeled as healthy_metal : 1
# 7a3a7e20 labeled as healthy_metal : 1
# 7a39bf58 labeled as healthy_metal : 1
# 7a27b542 labeled as healthy_metal : 1
# 7a3609b2 labeled as healthy_metal : 1
# 7a1deb5c labeled as healthy_metal : 1
# 7a323be8 labeled as healthy_metal : 1
# 7a408824 labeled as healthy_metal : 1
# 7a3908ba labeled as healthy_metal : 1
# 7a2d0ce0 labeled as healthy_metal : 1
# 7a2e8566 labeled as healthy_metal : 1
# 7a440d64 labeled as healthy_metal : 1
# 7a23287e labeled as healthy_metal : 1
# 7a281f3c labeled as healthy_metal : 1
# 7a1d98c8 labeled as healthy_metal : 1
# 7a2d353a labeled as healthy_metal : 1
# 7a29f1f4 labeled as healthy_metal : 1
# 7a2c0606 labeled as healthy_metal : 1
# 7a255392 labeled as healthy_metal : 1
# 7a372072 labeled as healthy_metal : 1
# 7a21f7d8 labeled as healthy_metal : 1
# 7a37c3ec labeled as healthy_metal : 1
# 7a3c038a labeled as healthy_metal : 1
# 7a3bc2e4 labeled as healthy_metal : 1
# 7a396ec2 labeled as healthy_metal : 1
# 7a27747e labeled as healthy_metal : 1
# 7a36e9a4 labeled as healthy_metal : 1
# 7a1d0ff2 labeled as healthy_metal : 1
# 7a43ede8 labeled as healthy_metal : 1
# 7a3f9c98 labeled as healthy_metal : 1
# 7a25824a labeled as healthy_metal : 1
# 7a3b7e9c labeled as healthy_metal : 1
# 7a352114 labeled as healthy_metal : 1
# 7a1e13ca labeled as healthy_metal : 1
# 7a366f42 labeled as healthy_metal : 1
# 7a3e8b8c labeled as healthy_metal : 1
# 7a38eba0 labeled as healthy_metal : 1
# 7a241996 labeled as healthy_metal : 1
# 7a3aff44 labeled as healthy_metal : 1
# 7a1ccd44 labeled as healthy_metal : 1
# 7a3a0ba2 labeled as healthy_metal : 1
# 7a1f4628 labeled as healthy_metal : 1
# 7a1e6fb4 labeled as healthy_metal : 1
# 7a21ba7a labeled as healthy_metal : 1
# 7a3881d8 labeled as healthy_metal : 1
# 7a2a6a58 labeled as healthy_metal : 1
# 7a37b1c2 labeled as healthy_metal : 1
# 7a2feef6 labeled as healthy_metal : 1
# 7a2d1816 labeled as healthy_metal : 1
# 7a3a69f8 labeled as healthy_metal : 1
# 7a21e680 labeled as healthy_metal : 1
# 7a40fbba labeled as healthy_metal : 1
# 7a43354c labeled as healthy_metal : 1
# 7a42a80c labeled as healthy_metal : 1
# 7a21c9c0 labeled as healthy_metal : 1
# 7a393326 labeled as healthy_metal : 1
# 7a3aa134 labeled as healthy_metal : 1
# 7a20764c labeled as healthy_metal : 1
# 7a26419e labeled as healthy_metal : 1
# 7a220d0e labeled as healthy_metal : 1
# 7a250a68 labeled as healthy_metal : 1
# 7a3ba930 labeled as healthy_metal : 1
# 7a357542 labeled as healthy_metal : 1
# 7a307cb8 labeled as healthy_metal : 1
# 7a3f347e labeled as healthy_metal : 1
# 7a2d6816 labeled as healthy_metal : 1
# 7a371f32 labeled as healthy_metal : 1
# 7a3b4846 labeled as healthy_metal : 1
# 7a35fc06 labeled as healthy_metal : 1
# 7a3d43c6 labeled as healthy_metal : 1
# 7a3d26e8 labeled as healthy_metal : 1
# 7a2205ac labeled as healthy_metal : 1
# 7a405dc2 labeled as healthy_metal : 1
# 7a3c2d42 labeled as healthy_metal : 1
# 7a213802 labeled as healthy_metal : 1
# 7a329f02 labeled as healthy_metal : 1
# 7a428ec6 labeled as healthy_metal : 1
# 7a2f1fd0 labeled as healthy_metal : 1
# 7a336ff4 labeled as healthy_metal : 1
# 7a1fc922 labeled as healthy_metal : 1
# 7a203c9a labeled as healthy_metal : 1
# 7a39a7ca labeled as healthy_metal : 1
# 7a1f597e labeled as healthy_metal : 1
# 7a249b82 labeled as healthy_metal : 1
# 7a41b9ce labeled as healthy_metal : 1
# 7a27ddd8 labeled as healthy_metal : 1
# 7a2705ac labeled as healthy_metal : 1
# 7a2d1d7a labeled as healthy_metal : 1
# 7a2ae384 labeled as healthy_metal : 1
# 7a3e5e64 labeled as healthy_metal : 1
# 7a34c6b0 labeled as healthy_metal : 1
# 7a3f30f0 labeled as healthy_metal : 1
# 7a210544 labeled as healthy_metal : 1
# 7a3fbf84 labeled as healthy_metal : 1
# 7a2aa810 labeled as healthy_metal : 1
# 7a38cb48 labeled as healthy_metal : 1
# 7a365e44 labeled as healthy_metal : 1
# 7a31ef58 labeled as healthy_metal : 1
# 7a219f4a labeled as healthy_metal : 1
# 7a44abfc labeled as healthy_metal : 1
# 7a41660e labeled as healthy_metal : 1
# 7a44493c labeled as healthy_metal : 1
# 7a1fb7c0 labeled as healthy_metal : 1
# 7a3132e8 labeled as healthy_metal : 1
# 7a3c13a2 labeled as healthy_metal : 1
# 7a2cc6ae labeled as healthy_metal : 1
# 7a1e5d6c labeled as healthy_metal : 1
# 7a3f4ec8 labeled as healthy_metal : 1
# 7a1cf40e labeled as healthy_metal : 1
# 7a2f4564 labeled as healthy_metal : 1
# 7a354d88 labeled as healthy_metal : 1
# 7a4256b8 labeled as healthy_metal : 1
# 7a1ef060 labeled as healthy_metal : 1
# 7a39ed7a labeled as healthy_metal : 1
# 7a326186 labeled as healthy_metal : 1
# 7a34d6be labeled as healthy_metal : 1
# 7a282a54 labeled as healthy_metal : 1
# 7a1f7c74 labeled as healthy_metal : 1
# 7a39eca8 labeled as healthy_metal : 1
# 7a1e8ab2 labeled as healthy_metal : 1
# 7a3cd0f8 labeled as healthy_metal : 1
# 7a2700a2 labeled as healthy_metal : 1
# 7a3da3d4 labeled as healthy_metal : 1
# 7a355986 labeled as healthy_metal : 1
# 7a30e810 labeled as healthy_metal : 1
# 7a201288 labeled as healthy_metal : 1
# 7a2e5c8a labeled as healthy_metal : 1
# 7a1e2bc6 labeled as healthy_metal : 1
# 7a39f720 labeled as healthy_metal : 1
# 7a344884 labeled as healthy_metal : 1
# 7a2d81a2 labeled as healthy_metal : 1
# 7a22a2e6 labeled as healthy_metal : 1
# 7a210bb6 labeled as healthy_metal : 1
# 7a2e84f8 labeled as healthy_metal : 1
# 7a286fb4 labeled as healthy_metal : 1
# 7a37478c labeled as healthy_metal : 1
# 7a23b51e labeled as healthy_metal : 1
# 7a1e3184 labeled as healthy_metal : 1
# 7a29721a labeled as healthy_metal : 1
# 7a2f60da labeled as healthy_metal : 1
# 7a294c5e labeled as healthy_metal : 1
# 7a259582 labeled as healthy_metal : 1
# 7a2b432e labeled as healthy_metal : 1
# 7a22f7a0 labeled as healthy_metal : 1
# 7a33ce7c labeled as healthy_metal : 1
# 7a285bfa labeled as healthy_metal : 1
# 7a2372f2 labeled as healthy_metal : 1
# 7a3aca7e labeled as healthy_metal : 1
# 7a328166 labeled as healthy_metal : 1
# 7a30efa4 labeled as healthy_metal : 1
# 7a23dde6 labeled as healthy_metal : 1
# 7a24e434 labeled as healthy_metal : 1
# 7a33521c labeled as healthy_metal : 1
# 7a443bc2 labeled as healthy_metal : 1
# 7a3f0cf6 labeled as healthy_metal : 1
# 7a39a0b8 labeled as healthy_metal : 1
# 7a209f78 labeled as healthy_metal : 1
# 7a218ac8 labeled as healthy_metal : 1
# 7a2f039c labeled as healthy_metal : 1
# 7a2abf4e labeled as healthy_metal : 1
# 7a3919ae labeled as healthy_metal : 1
# 7a3c182a labeled as healthy_metal : 1
# 7a3e4f32 labeled as healthy_metal : 1
# 7a37c068 labeled as healthy_metal : 1
# 7a42fe60 labeled as healthy_metal : 1
# 7a209a32 labeled as healthy_metal : 1
# 7a230a1a labeled as healthy_metal : 1
# 7a394654 labeled as healthy_metal : 1
# 7a242ef4 labeled as healthy_metal : 1
# 7a2cb5ba labeled as healthy_metal : 1
# 7a2f8e5c labeled as healthy_metal : 1
# 7a21d096 labeled as healthy_metal : 1
# 7a1dcb4a labeled as healthy_metal : 1
# 7a44cfe2 labeled as healthy_metal : 1
# 7a40cef6 labeled as healthy_metal : 1
# 7a39be18 labeled as healthy_metal : 1
# 7a31d04a labeled as healthy_metal : 1
# 7a3ef77a labeled as healthy_metal : 1
# 7a1d94d6 labeled as healthy_metal : 1
# 7a30a526 labeled as healthy_metal : 1
# 7a2cef9e labeled as healthy_metal : 1
# 7a21b818 labeled as healthy_metal : 1
# 7a1c94fa labeled as healthy_metal : 1
# 7a2ca304 labeled as healthy_metal : 1
# 7a28d7c4 labeled as healthy_metal : 1
# 7a43e82a labeled as healthy_metal : 1
# 7a3dc436 labeled as healthy_metal : 1
# 7a289e12 labeled as healthy_metal : 1
# 7a224558 labeled as healthy_metal : 1
# 7a3aa922 labeled as healthy_metal : 1
# 7a40ce2e labeled as healthy_metal : 1
# 7a414930 labeled as healthy_metal : 1
# 7a358064 labeled as healthy_metal : 1
# 7a3dae10 labeled as healthy_metal : 1
# 7a3d9894 labeled as healthy_metal : 1
# 7a21fd28 labeled as healthy_metal : 1
# 7a4314cc labeled as healthy_metal : 1
# 7a3804d8 labeled as healthy_metal : 1
# 7a441598 labeled as healthy_metal : 1
# 7a44c33a labeled as healthy_metal : 1
# 7a39e6cc labeled as healthy_metal : 1
# 7a212876 labeled as healthy_metal : 1
# 7a337c24 labeled as healthy_metal : 1
# 7a3d39da labeled as healthy_metal : 1
# 7a31b06a labeled as healthy_metal : 1
# 7a2f69f4 labeled as healthy_metal : 1
# 7a3f4a2c labeled as healthy_metal : 1
# 7a2be284 labeled as healthy_metal : 1
# 7a33c0d0 labeled as healthy_metal : 1
# 7a394eba labeled as healthy_metal : 1
# 7a21ebd0 labeled as healthy_metal : 1
# 7a3abdf4 labeled as healthy_metal : 1
# 7a3fee28 labeled as healthy_metal : 1
# 7a1cdb22 labeled as healthy_metal : 1
# 7a2cd0ae labeled as healthy_metal : 1
# 7a28ddaa labeled as healthy_metal : 1
# 7a3a5d3c labeled as healthy_metal : 1
# 7a41b1cc labeled as healthy_metal : 1
# 7a2223a2 labeled as healthy_metal : 1
# 7a3d04b0 labeled as healthy_metal : 1
# 7a22bda8 labeled as healthy_metal : 1
# 7a2576f6 labeled as healthy_metal : 1
# 7a384ec0 labeled as healthy_metal : 1
# 7a297ae4 labeled as healthy_metal : 1
# 7a21c81c labeled as healthy_metal : 1
# 7a3807f8 labeled as healthy_metal : 1
# 7a2e4182 labeled as healthy_metal : 1
# 7a26bae8 labeled as healthy_metal : 1
# 7a2e751c labeled as healthy_metal : 1
# 7a3bf20a labeled as healthy_metal : 1
# 7a35d582 labeled as healthy_metal : 1
# 7a421702 labeled as healthy_metal : 1
# 7a2a23cc labeled as healthy_metal : 1
# 7a3d4498 labeled as healthy_metal : 1
# 7a35d168 labeled as healthy_metal : 1
# 7a30c1b4 labeled as healthy_metal : 1
# 7a2fac98 labeled as healthy_metal : 1
# 7a2f3600 labeled as healthy_metal : 1
# 7a33ea06 labeled as healthy_metal : 1
# 7a3c3166 labeled as healthy_metal : 1
# 7a3ddfac labeled as healthy_metal : 1
# 7a26f24c labeled as healthy_metal : 1
# 7a31a3f4 labeled as healthy_metal : 1
# 7a25cb38 labeled as healthy_metal : 1
# 7a2302b8 labeled as healthy_metal : 1
# 7a21bf48 labeled as healthy_metal : 1
# 7a38b874 labeled as healthy_metal : 1
# 7a2158f0 labeled as healthy_metal : 1
# 7a32fa24 labeled as healthy_metal : 1
# 7a3ab610 labeled as healthy_metal : 1
# 7a1ccace labeled as healthy_metal : 1
# 7a31d824 labeled as healthy_metal : 1
# 7a307858 labeled as healthy_metal : 1
# 7a2466e4 labeled as healthy_metal : 1
# 7a31d6ee labeled as healthy_metal : 1
# 7a3a29c0 labeled as healthy_metal : 1
# 7a344172 labeled as healthy_metal : 1
# 7a1e2004 labeled as healthy_metal : 1
# 7a33c486 labeled as healthy_metal : 1
# 7a329868 labeled as healthy_metal : 1
# 7a1db24a labeled as healthy_metal : 1
# 7a2a5748 labeled as healthy_metal : 1
# 7a3a432e labeled as healthy_metal : 1
# 7a445a4e labeled as healthy_metal : 1
# 7a43f0d6 labeled as healthy_metal : 1
# 7a3db784 labeled as healthy_metal : 1
# 7a3a24de labeled as healthy_metal : 1
# 7a2fb8f0 labeled as healthy_metal : 1
# 7a3a943c labeled as healthy_metal : 1
# 7a29a4ba labeled as healthy_metal : 1
# 7a28856c labeled as healthy_metal : 1
# 7a4326ce labeled as healthy_metal : 1
# 7a29a23a labeled as healthy_metal : 1
# 7a2bf300 labeled as healthy_metal : 1
# 7a262088 labeled as healthy_metal : 1
# 7a3bd810 labeled as healthy_metal : 1
# 7a29a80c labeled as healthy_metal : 1
# 7a396238 labeled as healthy_metal : 1
# 7a4217e8 labeled as healthy_metal : 1
# 7a2f1e22 labeled as healthy_metal : 1
# 7a44626e labeled as healthy_metal : 1
# 7a1fb4f0 labeled as healthy_metal : 1
# 7a4336fa labeled as healthy_metal : 1
# 7a2ea06e labeled as healthy_metal : 1
# 7a3e9366 labeled as healthy_metal : 1
# 7a1e7928 labeled as healthy_metal : 1
# 7a32480e labeled as healthy_metal : 1
# 7a2eb9fa labeled as healthy_metal : 1
# 7a284a7a labeled as healthy_metal : 1
# 7a2912ac labeled as healthy_metal : 1
# 7a3405fe labeled as healthy_metal : 1
# 7a400566 labeled as healthy_metal : 1
# 7a339768 labeled as healthy_metal : 1
# 7a449d10 labeled as healthy_metal : 1
# 7a3842ae labeled as healthy_metal : 1
# 7a21d0fa labeled as healthy_metal : 1
# 7a393df8 labeled as healthy_metal : 1
# 7a21fab2 labeled as healthy_metal : 1
# 7a37685c labeled as healthy_metal : 1
# 7a37ec14 labeled as healthy_metal : 1
# 7a1c8262 labeled as healthy_metal : 1
# 7a3b5f70 labeled as healthy_metal : 1
# 7a32f2c2 labeled as healthy_metal : 1
# 7a2226ea labeled as healthy_metal : 1
# 7a2f8a38 labeled as healthy_metal : 1
# 7a3e0784 labeled as healthy_metal : 1
# 7a2a87d6 labeled as healthy_metal : 1
# 7a28a1d2 labeled as healthy_metal : 1
# 7a29f190 labeled as healthy_metal : 1
# 7a2a75ca labeled as healthy_metal : 1
# 7a2be7de labeled as healthy_metal : 1
# 7a3a03c8 labeled as healthy_metal : 1
# 7a3a149e labeled as healthy_metal : 1
# 7a396666 labeled as healthy_metal : 1
# 7a2ad600 labeled as healthy_metal : 1
# 7a2f6e18 labeled as healthy_metal : 1
# 7a288b16 labeled as healthy_metal : 1
# 7a378ac6 labeled as healthy_metal : 1
# 7a22ebd4 labeled as healthy_metal : 1
# 7a2632b2 labeled as healthy_metal : 1
# 7a2de89a labeled as healthy_metal : 1
# 7a321118 labeled as healthy_metal : 1
# 7a241040 labeled as healthy_metal : 1
# 7a3015b6 labeled as healthy_metal : 1
# 7a34c43a labeled as healthy_metal : 1
# 7a3de07e labeled as healthy_metal : 1
# 7a32badc labeled as healthy_metal : 1
# 7a3226ee labeled as healthy_metal : 1
# 7a3e764c labeled as healthy_metal : 1
# 7a3dfeba labeled as healthy_metal : 1
# 7a273360 labeled as healthy_metal : 1
# 7a37a93e labeled as healthy_metal : 1
# 7a3a2d30 labeled as healthy_metal : 1
# 7a3956b2 labeled as healthy_metal : 1
# 7a3d622a labeled as healthy_metal : 1
# 7a2672c2 labeled as healthy_metal : 1
# 7a3d6158 labeled as healthy_metal : 1
# 7a33c850 labeled as healthy_metal : 1
# 7a2b1908 labeled as healthy_metal : 1
# 7a2fc192 labeled as healthy_metal : 1
# 7a261c32 labeled as healthy_metal : 1
# 7a2352f4 labeled as healthy_metal : 1
# 7a3ee636 labeled as healthy_metal : 1
# 7a284886 labeled as healthy_metal : 1
# 7a269c48 labeled as healthy_metal : 1
# 7a2ec30a labeled as healthy_metal : 1
# 7a3fe4c8 labeled as healthy_metal : 1
# 7a351b4c labeled as healthy_metal : 1
# 7a2df59c labeled as healthy_metal : 1
# 7a39cfe8 labeled as healthy_metal : 1
# 7a3f31d6 labeled as healthy_metal : 1
# 7a2ab580 labeled as healthy_metal : 1
# 7a357cae labeled as healthy_metal : 1
# 7a3ceb74 labeled as healthy_metal : 1
# 7a43b6a2 labeled as healthy_metal : 1
# 7a207584 labeled as healthy_metal : 1
# 7a2615ac labeled as healthy_metal : 1
# 7a351584 labeled as healthy_metal : 1
# 7a1dbee8 labeled as healthy_metal : 1
# 7a320c72 labeled as healthy_metal : 1
# 7a3b1efc labeled as healthy_metal : 1
# 7a30909a labeled as healthy_metal : 1
# 7a3fe086 labeled as healthy_metal : 1
# 7a260346 labeled as healthy_metal : 1
# 7a1d9c60 labeled as healthy_metal : 1
# 7a34a91e labeled as healthy_metal : 1
# 7a1ddb12 labeled as healthy_metal : 1
# 7a24ff3c labeled as healthy_metal : 1
# 7a3408d8 labeled as healthy_metal : 1
# 7a30f648 labeled as healthy_metal : 1
# 7a2e083e labeled as healthy_metal : 1
# 7a21a616 labeled as healthy_metal : 1
# 7a287900 labeled as healthy_metal : 1
# 7a363518 labeled as healthy_metal : 1
# 7a1d87c0 labeled as healthy_metal : 1
# 7a3ae7de labeled as healthy_metal : 1
# 7a3fd988 labeled as healthy_metal : 1
# 7a3d585c labeled as healthy_metal : 1
# 7a1dce88 labeled as healthy_metal : 1
# 7a235dda labeled as healthy_metal : 1
# 7a3a574c labeled as healthy_metal : 1
# 7a3affa8 labeled as healthy_metal : 1
# 7a2e1806 labeled as healthy_metal : 1
# 7a3bce4c labeled as healthy_metal : 1
# 7a2b51de labeled as healthy_metal : 1
# 7a2636d6 labeled as healthy_metal : 1
# 7a401344 labeled as healthy_metal : 1
# 7a1e0178 labeled as healthy_metal : 1
# 7a40f0d4 labeled as healthy_metal : 1
# 7a23d5bc labeled as healthy_metal : 1
# 7a42a2e4 labeled as healthy_metal : 1
# 7a329516 labeled as healthy_metal : 1
# 7a1f6f72 labeled as healthy_metal : 1
# 7a3871ca labeled as healthy_metal : 1
# 7a230330 labeled as healthy_metal : 1
# 7a27017e labeled as healthy_metal : 1
# 7a38fffa labeled as healthy_metal : 1
# 7a441f70 labeled as healthy_metal : 1
# 7a3713a2 labeled as healthy_metal : 1
# 7a37a510 labeled as healthy_metal : 1
# 7a32e746 labeled as healthy_metal : 1
# 7a2ba13e labeled as healthy_metal : 1
# 7a3f275e labeled as healthy_metal : 1
# 7a226efc labeled as healthy_metal : 1
# 7a32204a labeled as healthy_metal : 1
# 7a24c5ee labeled as healthy_metal : 1
# 7a2c48fa labeled as healthy_metal : 1
# 7a373440 labeled as healthy_metal : 1
# 7a1e0452 labeled as healthy_metal : 1
# 7a223bee labeled as healthy_metal : 1
# 7a2416f8 labeled as healthy_metal : 1
# 7a29bd7e labeled as healthy_metal : 1
# 7a337198 labeled as healthy_metal : 1
# 7a2b99dc labeled as healthy_metal : 1
# 7a2aa8d8 labeled as healthy_metal : 1
# 7a203a9c labeled as healthy_metal : 1
# 7a39dfa6 labeled as healthy_metal : 1
# 7a39843e labeled as healthy_metal : 1
# 7a24f7b2 labeled as healthy_metal : 1
# 7a3e1da0 labeled as healthy_metal : 1
# 7a2c4ec2 labeled as healthy_metal : 1
# 7a3b721c labeled as healthy_metal : 1
# 7a2d32c4 labeled as healthy_metal : 1
# 7a3b8cd4 labeled as healthy_metal : 1
# 7a3942f8 labeled as healthy_metal : 1
# 7a35c92a labeled as healthy_metal : 1
# 7a25a6bc labeled as healthy_metal : 1
# 7a396b66 labeled as healthy_metal : 1
# 7a3ad0dc labeled as healthy_metal : 1
# 7a29f56e labeled as healthy_metal : 1
# 7a2514a4 labeled as healthy_metal : 1
# 7a240e92 labeled as healthy_metal : 1
# 7a3e02d4 labeled as healthy_metal : 1
# 7a328d46 labeled as healthy_metal : 1
# 7a37a7fe labeled as healthy_metal : 1
# 7a1e8a4e labeled as healthy_metal : 1
# 7a1d80f4 labeled as healthy_metal : 1
# 7a36436e labeled as healthy_metal : 1
# 7a31c6cc labeled as healthy_metal : 1
# 7a2a6152 labeled as healthy_metal : 1
# 7a27da18 labeled as healthy_metal : 1
# 7a27889c labeled as healthy_metal : 1
# 7a38b162 labeled as healthy_metal : 1
# 7a318356 labeled as healthy_metal : 1
# 7a34d240 labeled as healthy_metal : 1
# 7a2beac2 labeled as healthy_metal : 1
# 7a25d8a8 labeled as healthy_metal : 1
# 7a2bb84a labeled as healthy_metal : 1
# 7a1d9990 labeled as healthy_metal : 1
# 7a250eaa labeled as healthy_metal : 1
# 7a253146 labeled as healthy_metal : 1
# 7a1d4cba labeled as healthy_metal : 1
# 7a3e5130 labeled as healthy_metal : 1
# 7a2f40c8 labeled as healthy_metal : 1
# 7a351bba labeled as healthy_metal : 1
# 7a4337d6 labeled as healthy_metal : 1
# 7a3071fa labeled as healthy_metal : 1
# 7a208a7e labeled as healthy_metal : 1
# 7a32ccac labeled as healthy_metal : 1
# 7a383868 labeled as healthy_metal : 1
# 7a29f7f8 labeled as healthy_metal : 1
# 7a2850ba labeled as healthy_metal : 1
# 7a2e8a5c labeled as healthy_metal : 1
# 7a2cac96 labeled as healthy_metal : 1
# 7a43174c labeled as healthy_metal : 1
# 7a224fb2 labeled as healthy_metal : 1
# 7a210f26 labeled as healthy_metal : 1
# 7a3af27e labeled as healthy_metal : 1
# 7a370740 labeled as healthy_metal : 1
# 7a415aa6 labeled as healthy_metal : 1
# 7a412798 labeled as healthy_metal : 1
# 7a3633d8 labeled as healthy_metal : 1
# 7a3bcd70 labeled as healthy_metal : 1
# 7a3866a8 labeled as healthy_metal : 1
# 7a3c888c labeled as healthy_metal : 1
# 7a202fb6 labeled as healthy_metal : 1
# 7a35841a labeled as healthy_metal : 1
# 7a29535c labeled as healthy_metal : 1
# 7a33a7b2 labeled as healthy_metal : 1
# 7a20c110 labeled as healthy_metal : 1
# 7a3f457c labeled as healthy_metal : 1
# 7a2c318a labeled as healthy_metal : 1
# 7a3c7c16 labeled as healthy_metal : 1
# 7a399f82 labeled as healthy_metal : 1
# 7a2e1e82 labeled as healthy_metal : 1
# 7a3e3c5e labeled as healthy_metal : 1
# 7a26daa0 labeled as healthy_metal : 1
# 7a377c52 labeled as healthy_metal : 1
# 7a2e7d14 labeled as healthy_metal : 1
# 7a232aae labeled as healthy_metal : 1
# 7a43f8f6 labeled as healthy_metal : 1
# 7a29cec2 labeled as healthy_metal : 1
# 7a3c545c labeled as healthy_metal : 1
# 7a444a0e labeled as healthy_metal : 1
# 7a441322 labeled as healthy_metal : 1
# 7a3f4a9a labeled as healthy_metal : 1
# 7a24ed12 labeled as healthy_metal : 1
# 7a39324a labeled as healthy_metal : 1
# 7a340040 labeled as healthy_metal : 1
# 7a2f4ef6 labeled as healthy_metal : 1
# 7a440b5c labeled as healthy_metal : 1
# 7a2b5292 labeled as healthy_metal : 1
# 7a354d1a labeled as healthy_metal : 1
# 7a3caeb6 labeled as healthy_metal : 1
# 7a3cfcd6 labeled as healthy_metal : 1
# 7a1f6a9a labeled as healthy_metal : 1
# 7a3dc292 labeled as healthy_metal : 1
# 7a354180 labeled as healthy_metal : 1
# 7a3094c8 labeled as healthy_metal : 1
# 7a1e7234 labeled as healthy_metal : 1
# 7a406506 labeled as healthy_metal : 1
# 7a28cd7e labeled as healthy_metal : 1
# 7a3429b2 labeled as healthy_metal : 1
# 7a2e16c6 labeled as healthy_metal : 1
# 7a211c6e labeled as healthy_metal : 1
# 7a2d4016 labeled as healthy_metal : 1
# 7a2e50b4 labeled as healthy_metal : 1
# 7a1fdf84 labeled as healthy_metal : 1
# 7a356b60 labeled as healthy_metal : 1
# 7a24b2de labeled as healthy_metal : 1
# 7a2b871c labeled as healthy_metal : 1
# 7a2142d4 labeled as healthy_metal : 1
# 7a30fdc8 labeled as healthy_metal : 1
# 7a1fa55a labeled as healthy_metal : 1
# 7a1fa4ec labeled as healthy_metal : 1
# 7a3583ac labeled as healthy_metal : 1
# 7a321dc0 labeled as healthy_metal : 1
# 7a42bbb2 labeled as healthy_metal : 1
# 7a40f4bc labeled as healthy_metal : 1
# 7a2e3fd4 labeled as healthy_metal : 1
# 7a32240a labeled as healthy_metal : 1
# 7a350a62 labeled as healthy_metal : 1
# 7a42749a labeled as healthy_metal : 1
# 7a4281a6 labeled as healthy_metal : 1
# 7a1eaa92 labeled as healthy_metal : 1
# 7a242b84 labeled as healthy_metal : 1
# 7a25c034 labeled as healthy_metal : 1
# 7a26c90c labeled as healthy_metal : 1
# 7a3936dc labeled as healthy_metal : 1
# 7a22dd10 labeled as healthy_metal : 1
# 7a2dfde4 labeled as healthy_metal : 1
# 7a3a1886 labeled as healthy_metal : 1
# 7a2fccbe labeled as healthy_metal : 1
# 7a26f31e labeled as healthy_metal : 1
# 7a36ada4 labeled as healthy_metal : 1
# 7a27e4f4 labeled as healthy_metal : 1
# 7a229710 labeled as healthy_metal : 1
# 7a271808 labeled as healthy_metal : 1
# 7a352cfe labeled as healthy_metal : 1
# 7a34103a labeled as healthy_metal : 1
# 7a3fb598 labeled as healthy_metal : 1
# 7a41fcfe labeled as healthy_metal : 1
# 7a32f0b0 labeled as healthy_metal : 1
# 7a2fd420 labeled as healthy_metal : 1
# 7a359e0a labeled as healthy_metal : 1
# 7a34ccdc labeled as healthy_metal : 1
# 7a44374e labeled as healthy_metal : 1
# 7a412bbc labeled as healthy_metal : 1
# 7a43f554 labeled as healthy_metal : 1
# 7a356bc4 labeled as healthy_metal : 1
# 7a3803a2 labeled as healthy_metal : 1
# 7a3a1b74 labeled as healthy_metal : 1
# 7a357c4a labeled as healthy_metal : 1
# 7a372432 labeled as healthy_metal : 1
# 7a370182 labeled as healthy_metal : 1
# 7a314486 labeled as healthy_metal : 1
# 7a223e64 labeled as healthy_metal : 1
# 7a265af8 labeled as healthy_metal : 1
# 7a44b3ae labeled as healthy_metal : 1
# 7a2e94ca labeled as healthy_metal : 1
# 7a2793f0 labeled as healthy_metal : 1
# 7a2dc3b0 labeled as healthy_metal : 1
# 7a230092 labeled as healthy_metal : 1
# 7a2a2e4e labeled as healthy_metal : 1
# 7a1e890e labeled as healthy_metal : 1
# 7a365f0c labeled as healthy_metal : 1
# 7a22ced8 labeled as healthy_metal : 1
# 7a1dfa98 labeled as healthy_metal : 1
# 7a350c06 labeled as healthy_metal : 1
# 7a3bc208 labeled as healthy_metal : 1
# 7a2ac570 labeled as healthy_metal : 1
# 7a2a9ece labeled as healthy_metal : 1
# 7a28739c labeled as healthy_metal : 1
# 7a2474f4 labeled as healthy_metal : 1
# 7a2b6098 labeled as healthy_metal : 1
# 7a2f0586 labeled as healthy_metal : 1
# 7a41c004 labeled as healthy_metal : 1
# 7a36db3a labeled as healthy_metal : 1
# 7a3cb294 labeled as healthy_metal : 1
# 7a38431c labeled as healthy_metal : 1
# 7a4265e0 labeled as healthy_metal : 1
# 7a2143a6 labeled as healthy_metal : 1
# 7a1ef844 labeled as healthy_metal : 1
# 7a1e29be labeled as healthy_metal : 1
# 7a357eb6 labeled as healthy_metal : 1
# 7a25d268 labeled as healthy_metal : 1
# 7a2ef60e labeled as healthy_metal : 1
# 7a31ed50 labeled as healthy_metal : 1
# 7a27b204 labeled as healthy_metal : 1
# 7a1d49ea labeled as healthy_metal : 1
# 7a33fb54 labeled as healthy_metal : 1
# 7a35130e labeled as healthy_metal : 1
# 7a3521e6 labeled as healthy_metal : 1
# 7a29f6b8 labeled as healthy_metal : 1
# 7a3e997e labeled as healthy_metal : 1
# 7a34280e labeled as healthy_metal : 1
# 7a44d050 labeled as healthy_metal : 1
# 7a2024c6 labeled as healthy_metal : 1
# 7a2e870a labeled as healthy_metal : 1
# 7a3ef5d6 labeled as healthy_metal : 1
# 7a34fd2e labeled as healthy_metal : 1
# 7a203a38 labeled as healthy_metal : 1
# 7a3a9dd8 labeled as healthy_metal : 1
# 7a284e3a labeled as healthy_metal : 1
# 7a2c346e labeled as healthy_metal : 1
# 7a4195c0 labeled as healthy_metal : 1
# 7a1ffc44 labeled as healthy_metal : 1
# 7a40d176 labeled as healthy_metal : 1
# 7a2984e4 labeled as healthy_metal : 1
# 7a36ce06 labeled as healthy_metal : 1
# 7a32c18a labeled as healthy_metal : 1
# 7a3e50cc labeled as healthy_metal : 1
# 7a41c522 labeled as healthy_metal : 1
# 7a2fa02c labeled as healthy_metal : 1
# 7a394d0c labeled as healthy_metal : 1
# 7a238a9e labeled as healthy_metal : 1
# 7a246450 labeled as healthy_metal : 1
# 7a3772b6 labeled as healthy_metal : 1
# 7a3696b6 labeled as healthy_metal : 1
# 7a3b2e6a labeled as healthy_metal : 1
# 7a35e324 labeled as healthy_metal : 1
# 7a2fe99c labeled as healthy_metal : 1
# 7a34af2c labeled as healthy_metal : 1
# 7a1ef628 labeled as healthy_metal : 1
# 7a42f3ac labeled as healthy_metal : 1
# 7a38fd16 labeled as healthy_metal : 1
# 7a3ea518 labeled as healthy_metal : 1
# 7a40221c labeled as healthy_metal : 1
# 7a1ccce0 labeled as healthy_metal : 1
# 7a3b42e2 labeled as healthy_metal : 1
# 7a1f1478 labeled as healthy_metal : 1
# 7a2e63f6 labeled as healthy_metal : 1
# 7a304c2a labeled as healthy_metal : 1
# 7a285ab0 labeled as healthy_metal : 1
# 7a3b9e5e labeled as healthy_metal : 1
# 7a1e88aa labeled as healthy_metal : 1
# 7a3d4786 labeled as healthy_metal : 1
# 7a298ec6 labeled as healthy_metal : 1
# 7a260ba2 labeled as healthy_metal : 1
# 7a3d5a64 labeled as healthy_metal : 1
# 7a33c3b4 labeled as healthy_metal : 1
# 7a344b68 labeled as healthy_metal : 1
# 7a2ad51a labeled as healthy_metal : 1
# 7a2eacd0 labeled as healthy_metal : 1
# 7a259730 labeled as healthy_metal : 1
# 7a34b06c labeled as healthy_metal : 1
# 7a218e06 labeled as healthy_metal : 1
# 7a28a768 labeled as healthy_metal : 1
# 7a24ed8a labeled as healthy_metal : 1
# 7a1c81ea labeled as healthy_metal : 1
# 7a341f1c labeled as healthy_metal : 1
# 7a281622 labeled as healthy_metal : 1
# 7a3b65a6 labeled as healthy_metal : 1
# 7a36797e labeled as healthy_metal : 1
# 7a322a40 labeled as healthy_metal : 1
# 7a3a4b80 labeled as healthy_metal : 1
# 7a3ebefe labeled as healthy_metal : 1
# 7a262e20 labeled as healthy_metal : 1
# 7a26e306 labeled as healthy_metal : 1
# 7a41ae0c labeled as healthy_metal : 1
# 7a31cfe6 labeled as healthy_metal : 1
# 7a3595d6 labeled as healthy_metal : 1
# 7a1eabc8 labeled as healthy_metal : 1
# 7a3a1106 labeled as healthy_metal : 1
# 7a2d6f82 labeled as healthy_metal : 1
# 7a3925c0 labeled as healthy_metal : 1
# 7a2cf57a labeled as healthy_metal : 1
# 7a2e1586 labeled as healthy_metal : 1
# 7a251940 labeled as healthy_metal : 1
# 7a272fdc labeled as healthy_metal : 1
# 7a348b32 labeled as healthy_metal : 1
# 7a333e44 labeled as healthy_metal : 1
# 7a4205aa labeled as healthy_metal : 1
# 7a41464c labeled as healthy_metal : 1
# 7a3d240e labeled as healthy_metal : 1
# 7a22369e labeled as healthy_metal : 1
# 7a20bef4 labeled as healthy_metal : 1
# 7a395b1c labeled as healthy_metal : 1
# 7a3743cc labeled as healthy_metal : 1
# 7a20f02c labeled as healthy_metal : 1
# 7a26231c labeled as healthy_metal : 1
# 7a31f868 labeled as healthy_metal : 1
# 7a2aae64 labeled as healthy_metal : 1
# 7a226876 labeled as healthy_metal : 1
# 7a2d9606 labeled as healthy_metal : 1
# 7a30658e labeled as healthy_metal : 1
# 7a38ce9a labeled as healthy_metal : 1
# 7a4026b8 labeled as healthy_metal : 1
# 7a3aa274 labeled as healthy_metal : 1
# 7a26754c labeled as healthy_metal : 1
# 7a369abc labeled as healthy_metal : 1
# 7a43babc labeled as healthy_metal : 1
# 7a3bec42 labeled as healthy_metal : 1
# 7a366ba0 labeled as healthy_metal : 1
# 7a3ff260 labeled as healthy_metal : 1
# 7a3c5b0a labeled as healthy_metal : 1
# 7a2c005c labeled as healthy_metal : 1
# 7a39c52a labeled as healthy_metal : 1
# 7a31c80c labeled as healthy_metal : 1
# 7a32e12e labeled as healthy_metal : 1
# 7a3ba8c2 labeled as healthy_metal : 1
# 7a3b2a46 labeled as healthy_metal : 1
# 7a253934 labeled as healthy_metal : 1
# 7a1fe51a labeled as healthy_metal : 1
# 7a428f2a labeled as healthy_metal : 1
# 7a4159d4 labeled as healthy_metal : 1
# 7a43a022 labeled as healthy_metal : 1
# 7a2e0e10 labeled as healthy_metal : 1
# 7a396c42 labeled as healthy_metal : 1
# 7a2b8f14 labeled as healthy_metal : 1
# 7a36aed0 labeled as healthy_metal : 1
# 7a221f88 labeled as healthy_metal : 1
# 7a2fb5a8 labeled as healthy_metal : 1
# 7a3910f8 labeled as healthy_metal : 1
# 7a21c286 labeled as healthy_metal : 1
# 7a2414dc labeled as healthy_metal : 1
# 7a3f6408 labeled as healthy_metal : 1
# 7a3f8802 labeled as healthy_metal : 1
# 7a41af4c labeled as healthy_metal : 1
# 7a31aa34 labeled as healthy_metal : 1
# 7a425d70 labeled as healthy_metal : 1
# 7a3251c8 labeled as healthy_metal : 1
# 7a261e62 labeled as healthy_metal : 1
# 7a2f9992 labeled as healthy_metal : 1
# 7a396e54 labeled as healthy_metal : 1
# 7a339556 labeled as healthy_metal : 1
# 7a323508 labeled as healthy_metal : 1
# 7a36b39e labeled as healthy_metal : 1
# 7a441390 labeled as healthy_metal : 1
# 7a2c6b96 labeled as healthy_metal : 1
# 7a3facc4 labeled as healthy_metal : 1
# 7a401416 labeled as healthy_metal : 1
# 7a28914c labeled as healthy_metal : 1
# 7a36ae08 labeled as healthy_metal : 1
# 7a354036 labeled as healthy_metal : 1
# 7a307ec0 labeled as healthy_metal : 1
# 7a336cac labeled as healthy_metal : 1
# 7a411b7c labeled as healthy_metal : 1
# 7a228842 labeled as healthy_metal : 1
# 7a26648a labeled as healthy_metal : 1
# 7a3106d8 labeled as healthy_metal : 1
# 7a2fa09a labeled as healthy_metal : 1
# 7a3db022 labeled as healthy_metal : 1
# 7a324e58 labeled as healthy_metal : 1
# 7a36b006 labeled as healthy_metal : 1
# 7a215d3c labeled as healthy_metal : 1
# 7a3abe62 labeled as healthy_metal : 1
# 7a2c903a labeled as healthy_metal : 1
# 7a3948d4 labeled as healthy_metal : 1
# 7a25249e labeled as healthy_metal : 1
# 7a42208a labeled as healthy_metal : 1
# 7a215c60 labeled as healthy_metal : 1
# 7a266714 labeled as healthy_metal : 1
# 7a3a6926 labeled as healthy_metal : 1
# 7a31d338 labeled as healthy_metal : 1
# 7a416a28 labeled as healthy_metal : 1
# 7a33ce18 labeled as healthy_metal : 1
# 7a34eb5e labeled as healthy_metal : 1
# 7a23a5ce labeled as healthy_metal : 1
# 7a3dbc02 labeled as healthy_metal : 1
# 7a21b2e6 labeled as healthy_metal : 1
# 7a358fa0 labeled as healthy_metal : 1
# 7a370394 labeled as healthy_metal : 1
# 7a23498a labeled as healthy_metal : 1
# 7a2cbdb2 labeled as healthy_metal : 1
# 7a3860ae labeled as healthy_metal : 1
# 7a32e61a labeled as healthy_metal : 1
# 7a31da36 labeled as healthy_metal : 1
# 7a243110 labeled as healthy_metal : 1
# 7a3b8ee6 labeled as healthy_metal : 1
# 7a3d86ec labeled as healthy_metal : 1
# 7a3ad49c labeled as healthy_metal : 1
# 7a2abff8 labeled as healthy_metal : 1
# 7a3c9b7e labeled as healthy_metal : 1
# 7a2b245c labeled as healthy_metal : 1
# 7a2c6d3a labeled as healthy_metal : 1
# 7a211a66 labeled as healthy_metal : 1
# 7a2fbca6 labeled as healthy_metal : 1
# 7a35bac0 labeled as healthy_metal : 1
# 7a215bfc labeled as healthy_metal : 1
# 7a3cef98 labeled as healthy_metal : 1
# 7a2138d4 labeled as healthy_metal : 1
# 7a2d042a labeled as healthy_metal : 1
# 7a2bce0c labeled as healthy_metal : 1
# 7a3380fc labeled as healthy_metal : 1
# 7a2533c6 labeled as healthy_metal : 1
# 7a1ef132 labeled as healthy_metal : 1
# 7a42fbe0 labeled as healthy_metal : 1
# 7a1db376 labeled as healthy_metal : 1
# 7a3d3eda labeled as healthy_metal : 1
# 7a34a27a labeled as healthy_metal : 1
# 7a42977c labeled as healthy_metal : 1
# 7a3f595e labeled as healthy_metal : 1
# 7a3bb326 labeled as healthy_metal : 1
# 7a396bd4 labeled as healthy_metal : 1
# 7a391594 labeled as healthy_metal : 1
# 7a2e909c labeled as healthy_metal : 1
# 7a3ebe2c labeled as healthy_metal : 1
# 7a221740 labeled as healthy_metal : 1
# 7a33290e labeled as healthy_metal : 1
# 7a265a8a labeled as healthy_metal : 1
# 7a254708 labeled as healthy_metal : 1
# 7a25235e labeled as healthy_metal : 1
# 7a3a8a46 labeled as healthy_metal : 1
# 7a32038a labeled as healthy_metal : 1
# 7a34979e labeled as healthy_metal : 1
# 7a2ba49a labeled as healthy_metal : 1
# 7a3ed5c4 labeled as healthy_metal : 1
# 7a2db55a labeled as healthy_metal : 1
# 7a2410a4 labeled as healthy_metal : 1
# 7a4071fe labeled as healthy_metal : 1
# 7a1d3f9a labeled as healthy_metal : 1
# 7a31fa0c labeled as healthy_metal : 1
# 7a259302 labeled as healthy_metal : 1
# 7a3b16a0 labeled as healthy_metal : 1
# 7a1f2a08 labeled as healthy_metal : 1
# 7a34fc5c labeled as healthy_metal : 1
# 7a1d044e labeled as healthy_metal : 1
# 7a412360 labeled as healthy_metal : 1
# 7a288882 labeled as healthy_metal : 1
# 7a408108 labeled as healthy_metal : 1
# 7a316d94 labeled as healthy_metal : 1
# 7a3ac722 labeled as healthy_metal : 1
# 7a4202c6 labeled as healthy_metal : 1
# 7a3f9bbc labeled as healthy_metal : 1
# 7a332ff8 labeled as healthy_metal : 1
# 7a3e122e labeled as healthy_metal : 1
# 7a38d822 labeled as healthy_metal : 1
# 7a3893e4 labeled as healthy_metal : 1
# 7a1f9f88 labeled as healthy_metal : 1
# 7a3f9dd8 labeled as healthy_metal : 1
# 7a248dd6 labeled as healthy_metal : 1
# 7a240e24 labeled as healthy_metal : 1
# 7a1ed558 labeled as healthy_metal : 1
# 7a2c2b40 labeled as healthy_metal : 1
# 7a2f0518 labeled as healthy_metal : 1
# 7a2b1656 labeled as healthy_metal : 1
# 7a299826 labeled as healthy_metal : 1
# 7a3adb54 labeled as healthy_metal : 1
# 7a2d3cce labeled as healthy_metal : 1
# 7a2ce166 labeled as healthy_metal : 1
# 7a34c8c2 labeled as healthy_metal : 1
# 7a319e04 labeled as healthy_metal : 1
# 7a1f31b0 labeled as healthy_metal : 1
# 7a389164 labeled as healthy_metal : 1
# 7a1dc3b6 labeled as healthy_metal : 1
# 7a2680aa labeled as healthy_metal : 1
# 7a379fd4 labeled as healthy_metal : 1
# 7a34c57a labeled as healthy_metal : 1
# 7a41fc90 labeled as healthy_metal : 1
# 7a1fb194 labeled as healthy_metal : 1
# 7a3f8488 labeled as healthy_metal : 1
# 7a20d0ba labeled as healthy_metal : 1
# 7a44d12c labeled as healthy_metal : 1
# 7a297cf6 labeled as healthy_metal : 1
# 7a3c1aaa labeled as healthy_metal : 1
# 7a1e757c labeled as healthy_metal : 1
# 7a43996a labeled as healthy_metal : 1
# 7a3fd3f2 labeled as healthy_metal : 1
# 7a2518d2 labeled as healthy_metal : 1
# 7a379a66 labeled as healthy_metal : 1
# 7a22e152 labeled as healthy_metal : 1
# 7a3e6d46 labeled as healthy_metal : 1
# 7a3bfc0a labeled as healthy_metal : 1
# 7a254988 labeled as healthy_metal : 1
# 7a42805c labeled as healthy_metal : 1
# 7a4454fe labeled as healthy_metal : 1
# 7a2086e6 labeled as healthy_metal : 1
# 7a2f5d10 labeled as healthy_metal : 1
# 7a23b58c labeled as healthy_metal : 1
# 7a29a65e labeled as healthy_metal : 1
# 7a39d344 labeled as healthy_metal : 1
# 7a2f3c04 labeled as healthy_metal : 1
# 7a2f0f2c labeled as healthy_metal : 1
# 7a1d02b4 labeled as healthy_metal : 1
# 7a2bf882 labeled as healthy_metal : 1
# 7a3bde3c labeled as healthy_metal : 1
# 7a2f5a90 labeled as healthy_metal : 1
# 7a2d2504 labeled as healthy_metal : 1
# 7a25ff2c labeled as healthy_metal : 1
# 7a25d344 labeled as healthy_metal : 1
# 7a2f6210 labeled as healthy_metal : 1
# 7a3787ec labeled as healthy_metal : 1
# 7a408680 labeled as healthy_metal : 1
# 7a37385a labeled as healthy_metal : 1
# 7a21579c labeled as healthy_metal : 1
# 7a1e1500 labeled as healthy_metal : 1
# 7a1fec86 labeled as healthy_metal : 1
# 7a3bcf82 labeled as healthy_metal : 1
# 7a2cc78a labeled as healthy_metal : 1
# 7a23aaf6 labeled as healthy_metal : 1
# 7a3ce17e labeled as healthy_metal : 1
# 7a3a853c labeled as healthy_metal : 1
# 7a243a98 labeled as healthy_metal : 1
# 7a27b5ec labeled as healthy_metal : 1
# 7a42ca76 labeled as healthy_metal : 1
# 7a43f342 labeled as healthy_metal : 1
# 7a31bf56 labeled as healthy_metal : 1
# 7a39cb56 labeled as healthy_metal : 1
# 7a261d0e labeled as healthy_metal : 1
# 7a380dd4 labeled as healthy_metal : 1
# 7a346a94 labeled as healthy_metal : 1
# 7a2934bc labeled as healthy_metal : 1
# 7a2a845c labeled as healthy_metal : 1
# 7a2283ce labeled as healthy_metal : 1
# 7a32e336 labeled as healthy_metal : 1
# 7a42490c labeled as healthy_metal : 1
# 7a3c75b8 labeled as healthy_metal : 1
# 7a37c66c labeled as healthy_metal : 1
# 7a1ddea0 labeled as healthy_metal : 1
# 7a3af5e4 labeled as healthy_metal : 1
# 7a3126fe labeled as healthy_metal : 1
# 7a3e05e0 labeled as healthy_metal : 1
# 7a3b8d42 labeled as healthy_metal : 1
# 7a38db6a labeled as healthy_metal : 1
# ...
# 7a3b62c2 labeled as irregular_metal : 3
# 7a3fda00 labeled as irregular_metal : 3
# 7a367212 labeled as irregular_metal : 3
# 7a42ebb4 labeled as irregular_metal : 3
# 7a2a00d6 labeled as irregular_metal : 3
# 7a3096e4 labeled as irregular_metal : 3
# 7a3f3398 labeled as irregular_metal : 3
# 7a3e96a4 labeled as irregular_metal : 3
# 7a2aeafa labeled as irregular_metal : 3
# 7a3238c8 labeled as irregular_metal : 3
# 7a39ede8 labeled as irregular_metal : 3
# 7a24ccc4 labeled as irregular_metal : 3
# 7a3e307e labeled as irregular_metal : 3
# 7a2fee88 labeled as irregular_metal : 3
# 7a41400c labeled as irregular_metal : 3
# 7a449770 labeled as irregular_metal : 3
# 7a2a4da2 labeled as irregular_metal : 3
# 7a1c6cf0 labeled as irregular_metal : 3
# 7a20cf84 labeled as irregular_metal : 3
# 7a24d7aa labeled as irregular_metal : 3
# 7a4264a0 labeled as irregular_metal : 3
# 7a37745a labeled as irregular_metal : 3
# 7a2a531a labeled as irregular_metal : 3
# 7a3b3eaa labeled as irregular_metal : 3
# 7a32c824 labeled as irregular_metal : 3
# 7a38ac58 labeled as irregular_metal : 3
# 7a39749e labeled as irregular_metal : 3
# 7a34ec94 labeled as irregular_metal : 3
# 7a2871d0 labeled as irregular_metal : 3
# 7a390d42 labeled as irregular_metal : 3
# 7a26d2b2 labeled as irregular_metal : 3
# 7a3de42a labeled as irregular_metal : 3
# 7a3de560 labeled as irregular_metal : 3
# 7a4154ca labeled as irregular_metal : 3
# 7a36ef44 labeled as irregular_metal : 3
# 7a3e4910 labeled as irregular_metal : 3
# 7a39a054 labeled as irregular_metal : 3
# 7a343204 labeled as irregular_metal : 3
# 7a23cd74 labeled as irregular_metal : 3
# 7a28c6a8 labeled as irregular_metal : 3
# 7a22b6aa labeled as irregular_metal : 3
# 7a3f4bda labeled as irregular_metal : 3
# 7a3987cc labeled as irregular_metal : 3
# 7a4497de labeled as irregular_metal : 3
# 7a2c7370 labeled as irregular_metal : 3
# 7a1d822a labeled as irregular_metal : 3
# 7a332206 labeled as irregular_metal : 3
# 7a40627c labeled as irregular_metal : 3
# 7a234c28 labeled as irregular_metal : 3
# 7a1eb80c labeled as irregular_metal : 3
# 7a3df06e labeled as irregular_metal : 3
# 7a29aa8c labeled as irregular_metal : 3
# 7a38ec04 labeled as irregular_metal : 3
# 7a39db14 labeled as irregular_metal : 3
# 7a3f2204 labeled as irregular_metal : 3
# 7a3caa10 labeled as irregular_metal : 3
# 7a2fcf34 labeled as irregular_metal : 3
# 7a21a27e labeled as irregular_metal : 3
# 7a40ffca labeled as irregular_metal : 3
# 7a2a0216 labeled as irregular_metal : 3
# 7a2f921c labeled as irregular_metal : 3
# 7a1d0e4e labeled as irregular_metal : 3
# 7a2b84ec labeled as irregular_metal : 3
# 7a3f864a labeled as irregular_metal : 3
# 7a25f7c0 labeled as irregular_metal : 3
# 7a3baa0c labeled as irregular_metal : 3
# 7a3bad5e labeled as irregular_metal : 3
# 7a383c82 labeled as irregular_metal : 3
# 7a37a5e2 labeled as irregular_metal : 3
# 7a1e6cbc labeled as irregular_metal : 3
# 7a3d776a labeled as irregular_metal : 3
# 7a2f8eca labeled as irregular_metal : 3
# 7a296e5a labeled as irregular_metal : 3
# 7a262614 labeled as irregular_metal : 3
# 7a43c282 labeled as irregular_metal : 3
# 7a425ae6 labeled as irregular_metal : 3
# 7a40f30e labeled as irregular_metal : 3
# 7a2f4a5a labeled as irregular_metal : 3
# 7a20928a labeled as irregular_metal : 3
# 7a2e0424 labeled as irregular_metal : 3
# 7a3bba24 labeled as irregular_metal : 3
# 7a3e476c labeled as irregular_metal : 3
# 7a1e0f56 labeled as irregular_metal : 3
# 7a3d5154 labeled as irregular_metal : 3
# 7a3c987c labeled as irregular_metal : 3
# 7a255a90 labeled as irregular_metal : 3
# 7a380cf8 labeled as irregular_metal : 3
# 7a2f516c labeled as irregular_metal : 3
# 7a3a240c labeled as irregular_metal : 3
# 7a1f5410 labeled as irregular_metal : 3
# 7a313284 labeled as irregular_metal : 3
# 7a25642c labeled as irregular_metal : 3
# 7a2b1c28 labeled as irregular_metal : 3
# 7a1ee87c labeled as irregular_metal : 3
# 7a3ab9c6 labeled as irregular_metal : 3
# 7a21da5a labeled as irregular_metal : 3
# 7a1e7e14 labeled as irregular_metal : 3
# 7a28462e labeled as irregular_metal : 3
# 7a220340 labeled as irregular_metal : 3
# 7a1d7618 labeled as irregular_metal : 3
# 7a2ef118 labeled as irregular_metal : 3
# 7a2fe0f0 labeled as irregular_metal : 3
# 7a3e9848 labeled as irregular_metal : 3
# 7a26b552 labeled as irregular_metal : 3
# 7a27fd72 labeled as irregular_metal : 3
# 7a41ad9e labeled as irregular_metal : 3
# 7a3d6b26 labeled as irregular_metal : 3
# 7a41c662 labeled as irregular_metal : 3
# 7a3e11ca labeled as irregular_metal : 3
# 7a21a67a labeled as irregular_metal : 3
# 7a3d7012 labeled as irregular_metal : 3
# 7a3de01a labeled as irregular_metal : 3
# 7a393e66 labeled as irregular_metal : 3
# 7a2233c4 labeled as irregular_metal : 3
# 7a31e0da labeled as irregular_metal : 3
# 7a23fb82 labeled as irregular_metal : 3
# 7a268622 labeled as irregular_metal : 3
# 7a30a378 labeled as irregular_metal : 3
# 7a3f7f74 labeled as irregular_metal : 3
# 7a2229d8 labeled as irregular_metal : 3
# 7a3faa3a labeled as irregular_metal : 3
# 7a2e9e52 labeled as irregular_metal : 3
# 7a259d84 labeled as irregular_metal : 3
# 7a31d680 labeled as irregular_metal : 3
# 7a2c9aa8 labeled as irregular_metal : 3
# 7a2dfb00 labeled as irregular_metal : 3
# 7a308bf4 labeled as irregular_metal : 3
# 7a3a9af4 labeled as irregular_metal : 3
# 7a32a452 labeled as irregular_metal : 3
# 7a39721e labeled as irregular_metal : 3
# 7a2270aa labeled as irregular_metal : 3
# 7a22ff52 labeled as irregular_metal : 3
# 7a3c7194 labeled as irregular_metal : 3
# 7a21db2c labeled as irregular_metal : 3
# 7a38364c labeled as irregular_metal : 3
# 7a3f49b4 labeled as irregular_metal : 3
# 7a332ab2 labeled as irregular_metal : 3
# 7a37943a labeled as irregular_metal : 3
# 7a3e3a56 labeled as irregular_metal : 3
# 7a25cc78 labeled as irregular_metal : 3
# 7a2cbefc labeled as irregular_metal : 3
# 7a305328 labeled as irregular_metal : 3
# 7a39f0cc labeled as irregular_metal : 3
# 7a2bec70 labeled as irregular_metal : 3
# 7a2e05c8 labeled as irregular_metal : 3
# 7a410b6e labeled as irregular_metal : 3
# 7a24168a labeled as irregular_metal : 3
# 7a319cce labeled as irregular_metal : 3
# 7a22166e labeled as irregular_metal : 3
# 7a2460e0 labeled as irregular_metal : 3
# 7a2a5a18 labeled as irregular_metal : 3
# 7a3ef6a8 labeled as irregular_metal : 3
# 7a3827d8 labeled as irregular_metal : 3
# 7a2b86ae labeled as irregular_metal : 3
# 7a39c796 labeled as irregular_metal : 3
# 7a2ebe78 labeled as irregular_metal : 3
# 7a3999a6 labeled as irregular_metal : 3
# 7a27c3fc labeled as irregular_metal : 3
# 7a32d062 labeled as irregular_metal : 3
# 7a2b85c8 labeled as irregular_metal : 3
# 7a3fa1b6 labeled as irregular_metal : 3
# 7a2aadb0 labeled as irregular_metal : 3
# 7a1d1b00 labeled as irregular_metal : 3
# 7a31e210 labeled as irregular_metal : 3
# 7a3f2132 labeled as irregular_metal : 3
# 7a2ba508 labeled as irregular_metal : 3
# 7a269e5a labeled as irregular_metal : 3
# 7a2fcfa2 labeled as irregular_metal : 3
# 7a2e8c6e labeled as irregular_metal : 3
# 7a333f7a labeled as irregular_metal : 3
# 7a34a2e8 labeled as irregular_metal : 3
# 7a348920 labeled as irregular_metal : 3
# 7a2ebd38 labeled as irregular_metal : 3
# 7a412d60 labeled as irregular_metal : 3
# 7a43aafe labeled as irregular_metal : 3
# 7a40d3f6 labeled as irregular_metal : 3
# 7a2542da labeled as irregular_metal : 3
# 7a364440 labeled as irregular_metal : 3
# 7a2560d0 labeled as irregular_metal : 3
# 7a3e950a labeled as irregular_metal : 3
# 7a36a4d0 labeled as irregular_metal : 3
# 7a41257c labeled as irregular_metal : 3
# 7a30a080 labeled as irregular_metal : 3
# 7a43f1a8 labeled as irregular_metal : 3
# 7a29d8f4 labeled as irregular_metal : 3
# 7a2ae26c labeled as irregular_metal : 3
# 7a3c009c labeled as irregular_metal : 3
# 7a24d890 labeled as irregular_metal : 3
# 7a40ead0 labeled as irregular_metal : 3
# 7a424b46 labeled as irregular_metal : 3
# 7a374930 labeled as irregular_metal : 3
# 7a25e172 labeled as irregular_metal : 3
# 7a27d022 labeled as irregular_metal : 3
# 7a23248c labeled as irregular_metal : 3
# 7a1eca22 labeled as irregular_metal : 3
# 7a39fd74 labeled as irregular_metal : 3
# 7a402f0a labeled as irregular_metal : 3
# 7a3413d2 labeled as irregular_metal : 3
# 7a2c5638 labeled as irregular_metal : 3
# 7a40ccee labeled as irregular_metal : 3
# 7a354a36 labeled as irregular_metal : 3
# 7a3e1fa8 labeled as irregular_metal : 3
# 7a275566 labeled as irregular_metal : 3
# 7a358ab4 labeled as irregular_metal : 3
# 7a3b0dcc labeled as irregular_metal : 3
# 7a358b86 labeled as irregular_metal : 3
# 7a221538 labeled as irregular_metal : 3
# 7a1fed62 labeled as irregular_metal : 3
# 7a41f88a labeled as irregular_metal : 3
# 7a3c5f38 labeled as irregular_metal : 3
# 7a39a75c labeled as irregular_metal : 3
# 7a272b4a labeled as irregular_metal : 3
# 7a4178a6 labeled as irregular_metal : 3
# 7a44682c labeled as irregular_metal : 3
# 7a26b62e labeled as irregular_metal : 3
# 7a2528d6 labeled as irregular_metal : 3
# 7a2acc6e labeled as irregular_metal : 3
# 7a426ca2 labeled as irregular_metal : 3
# 7a226ae2 labeled as irregular_metal : 3
# 7a3e5270 labeled as irregular_metal : 3
# 7a26a9c2 labeled as irregular_metal : 3
# 7a2a8e98 labeled as irregular_metal : 3
# 7a1cd3f2 labeled as irregular_metal : 3
# 7a3c4200 labeled as irregular_metal : 3
# 7a2dde72 labeled as irregular_metal : 3
# 7a3b4b2a labeled as irregular_metal : 3
# 7a440fe4 labeled as irregular_metal : 3
# 7a40a408 labeled as irregular_metal : 3
# 7a4491bc labeled as irregular_metal : 3
# 7a31214a labeled as irregular_metal : 3
# 7a3001fc labeled as irregular_metal : 3
# 7a407c76 labeled as irregular_metal : 3
# 7a2bd08c labeled as irregular_metal : 3
# 7a349ae6 labeled as irregular_metal : 3
# 7a3ff3aa labeled as irregular_metal : 3
# 7a311344 labeled as irregular_metal : 3
# 7a31ac46 labeled as irregular_metal : 3
# 7a43f068 labeled as irregular_metal : 3
# 7a1d20f0 labeled as irregular_metal : 3
# 7a3fa148 labeled as irregular_metal : 3
# 7a4023ca labeled as irregular_metal : 3
# 7a3fd83e labeled as irregular_metal : 3
# 7a2d2e32 labeled as irregular_metal : 3
# 7a1e1924 labeled as irregular_metal : 3
# 7a1d848c labeled as irregular_metal : 3
# 7a3d56ae labeled as irregular_metal : 3
# 7a34154e labeled as irregular_metal : 3
# 7a29acda labeled as irregular_metal : 3
# 7a2ad4ac labeled as irregular_metal : 3
# 7a3af0d0 labeled as irregular_metal : 3
# 7a3002ce labeled as irregular_metal : 3
# 7a230b5a labeled as irregular_metal : 3
# 7a3b41a2 labeled as irregular_metal : 3
# 7a3f4e5a labeled as irregular_metal : 3
# 7a3ffd64 labeled as irregular_metal : 3
# 7a380334 labeled as irregular_metal : 3
# 7a3f2344 labeled as irregular_metal : 3
# 7a3c2cd4 labeled as irregular_metal : 3
# 7a42eea2 labeled as irregular_metal : 3
# 7a2aebc2 labeled as irregular_metal : 3
# 7a2a3920 labeled as irregular_metal : 3
# 7a3108ea labeled as irregular_metal : 3
# 7a29b8e2 labeled as irregular_metal : 3
# 7a22c424 labeled as irregular_metal : 3
# 7a321852 labeled as irregular_metal : 3
# 7a3e1b2a labeled as irregular_metal : 3
# 7a27a8d6 labeled as irregular_metal : 3
# 7a1ccc0e labeled as irregular_metal : 3
# 7a3bb9c0 labeled as irregular_metal : 3
# 7a24139c labeled as irregular_metal : 3
# 7a337fd0 labeled as irregular_metal : 3
# 7a3a4950 labeled as irregular_metal : 3
# 7a291b94 labeled as irregular_metal : 3
# 7a3dc710 labeled as irregular_metal : 3
# 7a3f894c labeled as irregular_metal : 3
# 7a1ee322 labeled as irregular_metal : 3
# 7a4035cc labeled as irregular_metal : 3
# 7a2fa6c6 labeled as irregular_metal : 3
# 7a372144 labeled as irregular_metal : 3
# 7a22b844 labeled as irregular_metal : 3
# 7a2082e0 labeled as irregular_metal : 3
# 7a3d12c0 labeled as irregular_metal : 3
# 7a229238 labeled as irregular_metal : 3
# 7a2f8330 labeled as irregular_metal : 3
# 7a3466d4 labeled as irregular_metal : 3
# 7a2ba0d0 labeled as irregular_metal : 3
# 7a3423d6 labeled as irregular_metal : 3
# 7a2d2dce labeled as irregular_metal : 3
# 7a3d0c1c labeled as irregular_metal : 3
# 7a2872f2 labeled as irregular_metal : 3
# 7a3a57b0 labeled as irregular_metal : 3
# 7a28b276 labeled as irregular_metal : 3
# 7a36ec56 labeled as irregular_metal : 3
# 7a32a7ae labeled as irregular_metal : 3
# 7a278248 labeled as irregular_metal : 3
# 7a1ef0c4 labeled as irregular_metal : 3
# 7a20be22 labeled as irregular_metal : 3
# 7a218596 labeled as irregular_metal : 3
# 7a2f4424 labeled as irregular_metal : 3
# 7a372d4c labeled as irregular_metal : 3
# 7a35c5e2 labeled as irregular_metal : 3
# 7a422788 labeled as irregular_metal : 3
# 7a41272a labeled as irregular_metal : 3
# 7a37536c labeled as irregular_metal : 3
# 7a442330 labeled as irregular_metal : 3
# 7a392c6e labeled as irregular_metal : 3
# 7a3e6274 labeled as irregular_metal : 3
# 7a279314 labeled as irregular_metal : 3
# 7a263816 labeled as irregular_metal : 3
# 7a3cc8b0 labeled as irregular_metal : 3
# 7a33c1a2 labeled as irregular_metal : 3
# 7a428d7c labeled as irregular_metal : 3
# 7a3cbffa labeled as irregular_metal : 3
# 7a298264 labeled as irregular_metal : 3
# 7a3ea64e labeled as irregular_metal : 3
# 7a3d1b6c labeled as irregular_metal : 3
# 7a3d1180 labeled as irregular_metal : 3
# 7a2444c0 labeled as irregular_metal : 3
# 7a2a1e36 labeled as irregular_metal : 3
# 7a3be26a labeled as irregular_metal : 3
# 7a213d3e labeled as irregular_metal : 3
# 7a21bbb0 labeled as irregular_metal : 3
# 7a20315a labeled as irregular_metal : 3
# 7a1e77e8 labeled as irregular_metal : 3
# 7a25f8f6 labeled as irregular_metal : 3
# 7a29fe56 labeled as irregular_metal : 3
# 7a2eb4aa labeled as irregular_metal : 3
# 7a3343f8 labeled as irregular_metal : 3
# 7a35a6f2 labeled as irregular_metal : 3
# 7a34bb20 labeled as irregular_metal : 3
# 7a40dbe4 labeled as irregular_metal : 3
# 7a1e6474 labeled as irregular_metal : 3
# 7a38bbbc labeled as irregular_metal : 3
# 7a36f7fa labeled as irregular_metal : 3
# 7a2b270e labeled as irregular_metal : 3
# 7a412fe0 labeled as irregular_metal : 3
# 7a3ad9a6 labeled as irregular_metal : 3
# 7a3a718c labeled as irregular_metal : 3
# 7a38b0f4 labeled as irregular_metal : 3
# 7a2b9da6 labeled as irregular_metal : 3
# 7a214478 labeled as irregular_metal : 3
# 7a42d502 labeled as irregular_metal : 3
# 7a2914e6 labeled as irregular_metal : 3
# 7a35e036 labeled as irregular_metal : 3
# 7a4209e2 labeled as irregular_metal : 3
# 7a24e010 labeled as irregular_metal : 3
# 7a244ec0 labeled as irregular_metal : 3
# 7a339628 labeled as irregular_metal : 3
# 7a311be6 labeled as irregular_metal : 3
# 7a225d72 labeled as irregular_metal : 3
# 7a3c0d6c labeled as irregular_metal : 3
# 7a38d4da labeled as irregular_metal : 3
# 7a391b52 labeled as irregular_metal : 3
# 7a3339d0 labeled as irregular_metal : 3
# 7a1db9b6 labeled as irregular_metal : 3
# 7a336342 labeled as irregular_metal : 3
# 7a3b5d5e labeled as irregular_metal : 3
# 7a3e9f46 labeled as irregular_metal : 3
# 7a325f7e labeled as irregular_metal : 3
# 7a3c600a labeled as irregular_metal : 3
# 7a330d7a labeled as irregular_metal : 3
# 7a1f8c14 labeled as irregular_metal : 3
# 7a1ede18 labeled as irregular_metal : 3
# 7a3eb580 labeled as irregular_metal : 3
# 7a31a1e2 labeled as irregular_metal : 3
# 7a3043e2 labeled as irregular_metal : 3
# 7a37f77c labeled as irregular_metal : 3
# 7a3eb3dc labeled as irregular_metal : 3
# 7a3f0c24 labeled as irregular_metal : 3
# 7a218cd0 labeled as irregular_metal : 3
# 7a1e63a2 labeled as irregular_metal : 3
# 7a247468 labeled as irregular_metal : 3
# 7a3438a8 labeled as irregular_metal : 3
# 7a1ee80e labeled as irregular_metal : 3
# 7a41cd6a labeled as irregular_metal : 3
# 7a21cf60 labeled as irregular_metal : 3
# 7a2a0432 labeled as irregular_metal : 3
# 7a2e64c8 labeled as irregular_metal : 3
# 7a37a790 labeled as irregular_metal : 3
# 7a3e1b8e labeled as irregular_metal : 3
# 7a29b400 labeled as irregular_metal : 3
# 7a3849a2 labeled as irregular_metal : 3
# 7a36d5e0 labeled as irregular_metal : 3
# 7a3a824e labeled as irregular_metal : 3
# 7a35102a labeled as irregular_metal : 3
# 7a285efc labeled as irregular_metal : 3
# 7a3b07b4 labeled as irregular_metal : 3
# 7a20d68c labeled as irregular_metal : 3
# 7a360944 labeled as other : 4
# 7a307a06 labeled as other : 4
# 7a3ec1f6 labeled as other : 4
# 7a3af35a labeled as other : 4
# 7a2e2be8 labeled as other : 4
# 7a220b06 labeled as other : 4
# 7a3f71c8 labeled as other : 4
# 7a319b84 labeled as other : 4
# 7a3e5342 labeled as other : 4
# 7a209b68 labeled as other : 4
# 7a1ccef2 labeled as other : 4
# 7a3f2628 labeled as other : 4
# 7a34c0e8 labeled as other : 4
# 7a277d70 labeled as other : 4
# 7a401c0e labeled as other : 4

# %%
features_train.head()
# Out:
#          id                                           features  label
# 0  7a20f7ac  [4.636075, 2.3204336, 1.4748516, -0.0, -0.0, 1...      0
# 1  7a38b298  [2.326549, 3.0096893, 0.1731861, 1.4067602, 0....      0
# 2  7a3a662e  [2.7476623, 1.8925416, -0.0, 0.87210643, -0.0,...      0
# 3  7a3d7d28  [6.3516073, 3.722457, 0.3522606, -0.0, -0.0, 4...      0
# 4  7a397142  [0.38750732, 0.010527623, -0.0, 5.6719933, 7.7...      0

# %%
import pickle
from os import makedirs
from os.path import exists

pickle_path = join('..', '..', 'pickles')
if not exists(pickle_path):
    makedirs(pickle_path)

with open(join(pickle_path, 'resnet50_features_' + region + '_train.pkl' ), 'wb') as f:
    pickle.dump(features_train, f)

# %% [markdown]
# ### Visualize the features
#
# Reduce the dimensionality to 2D using tSNE (https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
def plot_tSNE(features, labels=None, number_of_materials=5):
    if labels is None:
        labels = np.zeros((features.shape[0]))

    # Visualization_
    #pca_object = PCA(n_components=50)
    #pca_features = pca_object.fit_transform(features)
    tsne_features = TSNE(n_components=2).fit_transform(features)

    # define the colormap
    cmap = plt.cm.jet
    # extract all colors from the .jet map
    cmaplist = [cmap(i) for i in range(cmap.N)]
    # create the new map
    cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

    # define the bins and normalize
    bounds = np.linspace(0, number_of_materials, number_of_materials + 1)
    norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)
    
    print(tsne_features.shape)

    plt.figure()
    scat = plt.scatter(tsne_features[:, 0], tsne_features[:, 1], c=labels, cmap=cmap, norm=norm)
    cb = plt.colorbar(scat, spacing='proportional', ticks=bounds)

# %% [markdown]
# Convert features within the dataframe to a single matrix

# %%
feat_matrix = features_train['features'].to_numpy()
feat_matrix = np.column_stack(feat_matrix).transpose()

labels = features_train['label'].to_numpy()

# %%
plot_tSNE(feat_matrix, labels)

# %% [markdown]
# ## 2. Calculate features on the test data

# %% [markdown]
# This procedure is similar as for the training data, except that we do not know the labels and the folder with test images is not subdivided by material

# %%
def calculate_features_test(test_dir):
    
    # Initialize a dataframe for the features    
    columns = ['id', 'features']
    df_features = pd.DataFrame(columns=columns)

    # Walk through all images
    for root, dirs, files in os.walk(test_dir):
        for file in files:
            img_fp = join(root, file)
            id = file.split('.')[0]
            print("Calculate features for", id)

            # Pad if size is too small, preprocess
            img = image.load_img(img_fp, target_size=(224, 224))
            img_data = image.img_to_array(img)
            img_data = np.expand_dims(img_data, axis=0)
            img_data = preprocess_input(img_data)

            # Compute features 
            features = model.predict(img_data)
            features_np = np.array(features).flatten()

            df_features = df_features.append({'id': id ,
                                              'features': features_np},
                                             ignore_index=True)

    return df_features

# %%
features_test = calculate_features_test(test_dir)

# %%
features_test.head()

# %%
with open(join(pickle_path, 'inceptionv3_features_' + region + '_test.pkl' ), 'wb') as f:
    pickle.dump(features_test, f)
