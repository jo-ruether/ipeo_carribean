# %% [markdown]
# # Calculating features

# %%
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input

import numpy as np
import pandas as pd
from os.path import join
import os
# Out:
# Using TensorFlow backend.

# %%
regions = ['borde_rural', 'borde_soacha', 'mixco_1_and_ebenezer', 'mixco_3']

# %%
region = 'mixco_3'
train_dir = join('..', '..', 'data', region, 'roofs_train')
test_dir = join('..', '..', 'data', region, 'roofs_test')
materials = {'concrete_cement':0, 'healthy_metal':1, 'incomplete':2, 'irregular_metal':3, 'other':4}

# %% [markdown]
# Use a pretrained network to compute features from the images, which are later classified. Import the model from the Kerase library and remove the top layer by setting `include_top=False`. The last layer is pooled such that we get outputs of size 1x2048 instead of 7x7x2048. The pooling method `'max'` is chosen empirically.

# %%
model = ResNet50(weights='imagenet', include_top=False, pooling='max')
model.summary()

# %% [markdown]
# ## 1. Calculate features on the training data

# %% [markdown]
# The preprocessed data is stored in such a way, that every region has their own folder, that contains a subfolder defined as `train_dir` above. This folder again is subdivided by material. Images carry their `id` as filename.
#
# Traverse all images in their corresponding folders which indicate the material and use `model.predict()` to get the features.

# %%
def calculate_features_train(train_dir):
    
    # Initialize a dataframe for the features    
    columns = ['id', 'features', 'label']
    df_features = pd.DataFrame(columns=columns)
    
    data = []

    # Walk through all images
    for material in materials.keys():
        material_fp = join(train_dir, material)
        for root, dirs, files in os.walk(material_fp):
            for file in files:
                img_fp = join(material_fp, file)
                label = materials[material]
                id = file.split('.')[0]
                print(id, "labeled as", material, ":", label)

                # Pad if size is too small, preprocess
                img = image.load_img(img_fp, target_size=(224, 224))
                img_data = image.img_to_array(img)
                img_data = np.expand_dims(img_data, axis=0)
                img_data = preprocess_input(img_data)

                # Compute features 
                resnet50_feature = model.predict(img_data)
                resnet50_feature_np = np.array(resnet50_feature).flatten()

                data.append({'id': id ,
                             'features': resnet50_feature_np,
                             'label': label})
                #df_features = df_features.append({'id': id ,
                #                                  'features': resnet50_feature_np,
                #                                  'label': label}, ignore_index=True)
    
    df_features = pd.DataFrame(data)
    return df_features

# %% [markdown]
# The results are stored in a dataframe as shown below and saved to disk as a pickle file.

# %%
features_train = calculate_features_train(train_dir)
# Out:
# 7a1c6d7c labeled as concrete_cement : 0
# 7a1d078c labeled as concrete_cement : 0
# 7a1d2ff0 labeled as concrete_cement : 0
# 7a1d570a labeled as concrete_cement : 0
# 7a1d6042 labeled as concrete_cement : 0
# 7a1d8e1e labeled as concrete_cement : 0
# 7a1d99fe labeled as concrete_cement : 0
# 7a1d9b34 labeled as concrete_cement : 0
# 7a1e26e4 labeled as concrete_cement : 0
# 7a1e2f04 labeled as concrete_cement : 0
# 7a1e385a labeled as concrete_cement : 0
# 7a1e90c0 labeled as concrete_cement : 0
# 7a1e9750 labeled as concrete_cement : 0
# 7a1eb73a labeled as concrete_cement : 0
# 7a1ebf6e labeled as concrete_cement : 0
# 7a1ec87e labeled as concrete_cement : 0
# 7a1ecbd0 labeled as concrete_cement : 0
# 7a1f49fc labeled as concrete_cement : 0
# 7a1f63b0 labeled as concrete_cement : 0
# 7a1f76d4 labeled as concrete_cement : 0
# 7a1f9362 labeled as concrete_cement : 0
# 7a1fdd4a labeled as concrete_cement : 0
# 7a1fe93e labeled as concrete_cement : 0
# 7a214bda labeled as concrete_cement : 0
# 7a21585a labeled as concrete_cement : 0
# 7a21973e labeled as concrete_cement : 0
# 7a2221ea labeled as concrete_cement : 0
# 7a224346 labeled as concrete_cement : 0
# 7a226664 labeled as concrete_cement : 0
# 7a228aea labeled as concrete_cement : 0
# 7a22e2f6 labeled as concrete_cement : 0
# 7a22edfa labeled as concrete_cement : 0
# 7a233c06 labeled as concrete_cement : 0
# 7a236f6e labeled as concrete_cement : 0
# 7a23c8a6 labeled as concrete_cement : 0
# 7a23d3a0 labeled as concrete_cement : 0
# 7a241766 labeled as concrete_cement : 0
# 7a24280a labeled as concrete_cement : 0
# 7a2459f6 labeled as concrete_cement : 0
# 7a245cf8 labeled as concrete_cement : 0
# 7a24aac8 labeled as concrete_cement : 0
# 7a24ba22 labeled as concrete_cement : 0
# 7a24d5e8 labeled as concrete_cement : 0
# 7a24e100 labeled as concrete_cement : 0
# 7a250f7c labeled as concrete_cement : 0
# 7a253218 labeled as concrete_cement : 0
# 7a255950 labeled as concrete_cement : 0
# 7a25b3aa labeled as concrete_cement : 0
# 7a25ce9e labeled as concrete_cement : 0
# 7a25d704 labeled as concrete_cement : 0
# 7a262164 labeled as concrete_cement : 0
# 7a262894 labeled as concrete_cement : 0
# 7a2652ec labeled as concrete_cement : 0
# 7a266cdc labeled as concrete_cement : 0
# 7a267c72 labeled as concrete_cement : 0
# 7a267ce0 labeled as concrete_cement : 0
# 7a268118 labeled as concrete_cement : 0
# 7a26b0ac labeled as concrete_cement : 0
# 7a26b840 labeled as concrete_cement : 0
# 7a270a48 labeled as concrete_cement : 0
# 7a273dd8 labeled as concrete_cement : 0
# 7a27426a labeled as concrete_cement : 0
# 7a276fe2 labeled as concrete_cement : 0
# 7a28c1bc labeled as concrete_cement : 0
# 7a28c34c labeled as concrete_cement : 0
# 7a28ee30 labeled as concrete_cement : 0
# 7a2908b6 labeled as concrete_cement : 0
# 7a292c60 labeled as concrete_cement : 0
# 7a29a168 labeled as concrete_cement : 0
# 7a29c3c8 labeled as concrete_cement : 0
# 7a2a064e labeled as concrete_cement : 0
# 7a2b323a labeled as concrete_cement : 0
# 7a2b35d2 labeled as concrete_cement : 0
# 7a2b4ae0 labeled as concrete_cement : 0
# 7a2b8c12 labeled as concrete_cement : 0
# 7a2bbc14 labeled as concrete_cement : 0
# 7a2bd9b0 labeled as concrete_cement : 0
# 7a2bdcb2 labeled as concrete_cement : 0
# 7a2be004 labeled as concrete_cement : 0
# 7a2beb9e labeled as concrete_cement : 0
# 7a2c02d2 labeled as concrete_cement : 0
# 7a2c0728 labeled as concrete_cement : 0
# 7a2c28c0 labeled as concrete_cement : 0
# 7a2c4e5e labeled as concrete_cement : 0
# 7a2c5976 labeled as concrete_cement : 0
# 7a2c9c56 labeled as concrete_cement : 0
# 7a2ce026 labeled as concrete_cement : 0
# 7a2d02ea labeled as concrete_cement : 0
# 7a2d3904 labeled as concrete_cement : 0
# 7a2d637a labeled as concrete_cement : 0
# 7a2d77c0 labeled as concrete_cement : 0
# 7a2da39e labeled as concrete_cement : 0
# 7a2dca72 labeled as concrete_cement : 0
# 7a2e13e2 labeled as concrete_cement : 0
# 7a2e1798 labeled as concrete_cement : 0
# 7a2e19aa labeled as concrete_cement : 0
# 7a2e3156 labeled as concrete_cement : 0
# 7a2e3e94 labeled as concrete_cement : 0
# 7a2e7954 labeled as concrete_cement : 0
# 7a2e9b6e labeled as concrete_cement : 0
# 7a2ec3dc labeled as concrete_cement : 0
# 7a2f06bc labeled as concrete_cement : 0
# 7a2f258e labeled as concrete_cement : 0
# 7a2f2f02 labeled as concrete_cement : 0
# 7a2f3934 labeled as concrete_cement : 0
# 7a2fc05c labeled as concrete_cement : 0
# 7a306020 labeled as concrete_cement : 0
# 7a308e1a labeled as concrete_cement : 0
# 7a30cd44 labeled as concrete_cement : 0
# 7a312d98 labeled as concrete_cement : 0
# 7a313a54 labeled as concrete_cement : 0
# 7a3147ce labeled as concrete_cement : 0
# 7a314a44 labeled as concrete_cement : 0
# 7a316fa6 labeled as concrete_cement : 0
# 7a31c460 labeled as concrete_cement : 0
# 7a31cdde labeled as concrete_cement : 0
# 7a31d612 labeled as concrete_cement : 0
# 7a321ba4 labeled as concrete_cement : 0
# 7a324c46 labeled as concrete_cement : 0
# 7a32798c labeled as concrete_cement : 0
# 7a32b686 labeled as concrete_cement : 0
# 7a32fd76 labeled as concrete_cement : 0
# 7a33067c labeled as concrete_cement : 0
# 7a334182 labeled as concrete_cement : 0
# 7a335f1e labeled as concrete_cement : 0
# 7a337dc8 labeled as concrete_cement : 0
# 7a339b78 labeled as concrete_cement : 0
# 7a339de4 labeled as concrete_cement : 0
# 7a33a1ea labeled as concrete_cement : 0
# 7a33bf22 labeled as concrete_cement : 0
# 7a3435ba labeled as concrete_cement : 0
# 7a343db2 labeled as concrete_cement : 0
# 7a3478a4 labeled as concrete_cement : 0
# 7a349244 labeled as concrete_cement : 0
# 7a3502ec labeled as concrete_cement : 0
# 7a35c718 labeled as concrete_cement : 0
# 7a360a84 labeled as concrete_cement : 0
# 7a363090 labeled as concrete_cement : 0
# 7a3655c0 labeled as concrete_cement : 0
# 7a365624 labeled as concrete_cement : 0
# 7a36be16 labeled as concrete_cement : 0
# 7a36f4a8 labeled as concrete_cement : 0
# 7a36fb4c labeled as concrete_cement : 0
# 7a371474 labeled as concrete_cement : 0
# 7a37871a labeled as concrete_cement : 0
# 7a37c004 labeled as concrete_cement : 0
# 7a38127a labeled as concrete_cement : 0
# 7a38b734 labeled as concrete_cement : 0
# 7a38e4fc labeled as concrete_cement : 0
# 7a390568 labeled as concrete_cement : 0
# 7a3911ca labeled as concrete_cement : 0
# 7a394dde labeled as concrete_cement : 0
# 7a399e38 labeled as concrete_cement : 0
# 7a39bef4 labeled as concrete_cement : 0
# 7a39c732 labeled as concrete_cement : 0
# 7a39da42 labeled as concrete_cement : 0
# 7a3a09ae labeled as concrete_cement : 0
# 7a3a5e18 labeled as concrete_cement : 0
# 7a3a7768 labeled as concrete_cement : 0
# 7a3adf28 labeled as concrete_cement : 0
# 7a3af580 labeled as concrete_cement : 0
# 7a3b0318 labeled as concrete_cement : 0
# 7a3b0f0c labeled as concrete_cement : 0
# 7a3b4706 labeled as concrete_cement : 0
# 7a3b6182 labeled as concrete_cement : 0
# 7a3b6614 labeled as concrete_cement : 0
# 7a3baf02 labeled as concrete_cement : 0
# 7a3bd130 labeled as concrete_cement : 0
# 7a3beeb8 labeled as concrete_cement : 0
# 7a3c196a labeled as concrete_cement : 0
# 7a3c5a2e labeled as concrete_cement : 0
# 7a3c8594 labeled as concrete_cement : 0
# 7a3d2896 labeled as concrete_cement : 0
# 7a3d3a48 labeled as concrete_cement : 0
# 7a3d3c5a labeled as concrete_cement : 0
# 7a3d4646 labeled as concrete_cement : 0
# 7a3d4718 labeled as concrete_cement : 0
# 7a3d60ea labeled as concrete_cement : 0
# 7a3d80ca labeled as concrete_cement : 0
# 7a3da64a labeled as concrete_cement : 0
# 7a3daf50 labeled as concrete_cement : 0
# 7a3dcf44 labeled as concrete_cement : 0
# 7a3e0c0c labeled as concrete_cement : 0
# 7a3e2282 labeled as concrete_cement : 0
# 7a3e3646 labeled as concrete_cement : 0
# 7a3e3bfa labeled as concrete_cement : 0
# 7a3e62e2 labeled as concrete_cement : 0
# 7a3e9636 labeled as concrete_cement : 0
# 7a3ecb6a labeled as concrete_cement : 0
# 7a3ed0ce labeled as concrete_cement : 0
# 7a3f0512 labeled as concrete_cement : 0
# 7a3f08d2 labeled as concrete_cement : 0
# 7a3f117e labeled as concrete_cement : 0
# 7a3f2a10 labeled as concrete_cement : 0
# 7a3f2c5e labeled as concrete_cement : 0
# 7a3f5594 labeled as concrete_cement : 0
# 7a3f6476 labeled as concrete_cement : 0
# 7a3f97a2 labeled as concrete_cement : 0
# 7a3fb5fc labeled as concrete_cement : 0
# 7a3fe0f4 labeled as concrete_cement : 0
# 7a4042ba labeled as concrete_cement : 0
# 7a409c1a labeled as concrete_cement : 0
# 7a40adc2 labeled as concrete_cement : 0
# 7a40d324 labeled as concrete_cement : 0
# 7a41c798 labeled as concrete_cement : 0
# 7a41e048 labeled as concrete_cement : 0
# 7a42454c labeled as concrete_cement : 0
# 7a424f06 labeled as concrete_cement : 0
# 7a427fee labeled as concrete_cement : 0
# 7a42c206 labeled as concrete_cement : 0
# 7a42c936 labeled as concrete_cement : 0
# 7a43a87e labeled as concrete_cement : 0
# 7a43b06c labeled as concrete_cement : 0
# 7a43cf34 labeled as concrete_cement : 0
# 7a4413fe labeled as concrete_cement : 0
# 7a441c96 labeled as concrete_cement : 0
# 7a448690 labeled as concrete_cement : 0
# 7a1c4d74 labeled as healthy_metal : 1
# 7a1c5274 labeled as healthy_metal : 1
# 7a1c5daa labeled as healthy_metal : 1
# 7a1c6296 labeled as healthy_metal : 1
# 7a1c701a labeled as healthy_metal : 1
# 7a1c7484 labeled as healthy_metal : 1
# 7a1c7f38 labeled as healthy_metal : 1
# 7a1c887a labeled as healthy_metal : 1
# 7a1c88e8 labeled as healthy_metal : 1
# 7a1c964e labeled as healthy_metal : 1
# 7a1c9842 labeled as healthy_metal : 1
# 7a1c99a0 labeled as healthy_metal : 1
# 7a1ca3b4 labeled as healthy_metal : 1
# 7a1ca422 labeled as healthy_metal : 1
# 7a1cb516 labeled as healthy_metal : 1
# 7a1cb868 labeled as healthy_metal : 1
# 7a1cc844 labeled as healthy_metal : 1
# 7a1cc916 labeled as healthy_metal : 1
# 7a1cca60 labeled as healthy_metal : 1
# 7a1ccdb2 labeled as healthy_metal : 1
# 7a1cd05a labeled as healthy_metal : 1
# 7a1cd104 labeled as healthy_metal : 1
# 7a1cd6b8 labeled as healthy_metal : 1
# 7a1ce73e labeled as healthy_metal : 1
# 7a1ce7a2 labeled as healthy_metal : 1
# 7a1ce874 labeled as healthy_metal : 1
# 7a1ce946 labeled as healthy_metal : 1
# 7a1ce9aa labeled as healthy_metal : 1
# 7a1ceda6 labeled as healthy_metal : 1
# 7a1ceedc labeled as healthy_metal : 1
# 7a1cf670 labeled as healthy_metal : 1
# 7a1cfada labeled as healthy_metal : 1
# 7a1d0052 labeled as healthy_metal : 1
# 7a1d04bc labeled as healthy_metal : 1
# 7a1d0520 labeled as healthy_metal : 1
# 7a1d0bec labeled as healthy_metal : 1
# 7a1d0c5a labeled as healthy_metal : 1
# 7a1d0dea labeled as healthy_metal : 1
# 7a1d0ebc labeled as healthy_metal : 1
# 7a1d0f20 labeled as healthy_metal : 1
# 7a1d12cc labeled as healthy_metal : 1
# 7a1d1600 labeled as healthy_metal : 1
# 7a1d1736 labeled as healthy_metal : 1
# 7a1d192a labeled as healthy_metal : 1
# 7a1d1fc4 labeled as healthy_metal : 1
# 7a1d255a labeled as healthy_metal : 1
# 7a1d292e labeled as healthy_metal : 1
# 7a1d2d66 labeled as healthy_metal : 1
# 7a1d2f28 labeled as healthy_metal : 1
# 7a1d305e labeled as healthy_metal : 1
# 7a1d364e labeled as healthy_metal : 1
# 7a1d36b2 labeled as healthy_metal : 1
# 7a1d384c labeled as healthy_metal : 1
# 7a1d3c66 labeled as healthy_metal : 1
# 7a1d4580 labeled as healthy_metal : 1
# 7a1d46b6 labeled as healthy_metal : 1
# 7a1d51e2 labeled as healthy_metal : 1
# 7a1d54b2 labeled as healthy_metal : 1
# 7a1d5840 labeled as healthy_metal : 1
# 7a1d5912 labeled as healthy_metal : 1
# 7a1d5e3a labeled as healthy_metal : 1
# 7a1d5f70 labeled as healthy_metal : 1
# 7a1d6236 labeled as healthy_metal : 1
# 7a1d6e8e labeled as healthy_metal : 1
# 7a1d728a labeled as healthy_metal : 1
# 7a1d7352 labeled as healthy_metal : 1
# 7a1d767c labeled as healthy_metal : 1
# 7a1d7816 labeled as healthy_metal : 1
# 7a1d7c94 labeled as healthy_metal : 1
# 7a1d8626 labeled as healthy_metal : 1
# 7a1d8824 labeled as healthy_metal : 1
# 7a1d89be labeled as healthy_metal : 1
# 7a1d8ce8 labeled as healthy_metal : 1
# 7a1d8db0 labeled as healthy_metal : 1
# 7a1d8fae labeled as healthy_metal : 1
# 7a1d9012 labeled as healthy_metal : 1
# 7a1d9f26 labeled as healthy_metal : 1
# 7a1da12e labeled as healthy_metal : 1
# 7a1da2c8 labeled as healthy_metal : 1
# 7a1da782 labeled as healthy_metal : 1
# 7a1da7e6 labeled as healthy_metal : 1
# 7a1da8ae labeled as healthy_metal : 1
# 7a1da980 labeled as healthy_metal : 1
# 7a1daaac labeled as healthy_metal : 1
# 7a1dab7e labeled as healthy_metal : 1
# 7a1dabec labeled as healthy_metal : 1
# 7a1dadea labeled as healthy_metal : 1
# 7a1db56a labeled as healthy_metal : 1
# 7a1db75e labeled as healthy_metal : 1
# 7a1db88a labeled as healthy_metal : 1
# 7a1dbaec labeled as healthy_metal : 1
# 7a1dc1b8 labeled as healthy_metal : 1
# 7a1dc5b4 labeled as healthy_metal : 1
# 7a1dc618 labeled as healthy_metal : 1
# 7a1dc67c labeled as healthy_metal : 1
# 7a1dc7b2 labeled as healthy_metal : 1
# 7a1dc8e8 labeled as healthy_metal : 1
# 7a1dce24 labeled as healthy_metal : 1
# 7a1dd978 labeled as healthy_metal : 1
# 7a1df750 labeled as healthy_metal : 1
# 7a1df9e4 labeled as healthy_metal : 1
# 7a1dfdcc labeled as healthy_metal : 1
# 7a1dfe8a labeled as healthy_metal : 1
# 7a1e164a labeled as healthy_metal : 1
# 7a1e171c labeled as healthy_metal : 1
# 7a1e18c0 labeled as healthy_metal : 1
# 7a1e1a64 labeled as healthy_metal : 1
# 7a1e22f2 labeled as healthy_metal : 1
# 7a1e2c34 labeled as healthy_metal : 1
# 7a1e3990 labeled as healthy_metal : 1
# 7a1e3f94 labeled as healthy_metal : 1
# 7a1e4066 labeled as healthy_metal : 1
# 7a1e47a0 labeled as healthy_metal : 1
# 7a1e4804 labeled as healthy_metal : 1
# 7a1e4f52 labeled as healthy_metal : 1
# 7a1e50f6 labeled as healthy_metal : 1
# 7a1e5574 labeled as healthy_metal : 1
# 7a1e59f2 labeled as healthy_metal : 1
# 7a1e6410 labeled as healthy_metal : 1
# 7a1e6a14 labeled as healthy_metal : 1
# 7a1e6a96 labeled as healthy_metal : 1
# 7a1e6be0 labeled as healthy_metal : 1
# 7a1e6d2a labeled as healthy_metal : 1
# 7a1e6e74 labeled as healthy_metal : 1
# 7a1e7446 labeled as healthy_metal : 1
# 7a1e84fe labeled as healthy_metal : 1
# 7a1e883c labeled as healthy_metal : 1
# 7a1e8b84 labeled as healthy_metal : 1
# 7a1e8f8a labeled as healthy_metal : 1
# 7a1e9d18 labeled as healthy_metal : 1
# 7a1ea0c4 labeled as healthy_metal : 1
# 7a1ea66e labeled as healthy_metal : 1
# 7a1ea74a labeled as healthy_metal : 1
# 7a1ea8ee labeled as healthy_metal : 1
# 7a1eaaf6 labeled as healthy_metal : 1
# 7a1eb24e labeled as healthy_metal : 1
# 7a1eb2bc labeled as healthy_metal : 1
# 7a1eb32a labeled as healthy_metal : 1
# 7a1eb38e labeled as healthy_metal : 1
# 7a1eb9b0 labeled as healthy_metal : 1
# 7a1eba14 labeled as healthy_metal : 1
# 7a1ebc8a labeled as healthy_metal : 1
# 7a1ebdca labeled as healthy_metal : 1
# 7a1ec37e labeled as healthy_metal : 1
# 7a1ecde2 labeled as healthy_metal : 1
# 7a1ed134 labeled as healthy_metal : 1
# 7a1ed206 labeled as healthy_metal : 1
# 7a1ed63e labeled as healthy_metal : 1
# 7a1edf58 labeled as healthy_metal : 1
# 7a1ee106 labeled as healthy_metal : 1
# 7a1ee1e2 labeled as healthy_metal : 1
# 7a1ee94e labeled as healthy_metal : 1
# 7a1eeb56 labeled as healthy_metal : 1
# 7a1eebc4 labeled as healthy_metal : 1
# 7a1ef196 labeled as healthy_metal : 1
# 7a1ef704 labeled as healthy_metal : 1
# 7a1eface labeled as healthy_metal : 1
# 7a1efb32 labeled as healthy_metal : 1
# 7a1efe16 labeled as healthy_metal : 1
# 7a1efe7a labeled as healthy_metal : 1
# 7a1f010e labeled as healthy_metal : 1
# 7a1f0320 labeled as healthy_metal : 1
# 7a1f065e labeled as healthy_metal : 1
# 7a1f0b90 labeled as healthy_metal : 1
# 7a1f154a labeled as healthy_metal : 1
# 7a1f3368 labeled as healthy_metal : 1
# 7a1f34ee labeled as healthy_metal : 1
# 7a1f36a6 labeled as healthy_metal : 1
# 7a1f3782 labeled as healthy_metal : 1
# 7a1f39bc labeled as healthy_metal : 1
# 7a1f3afc labeled as healthy_metal : 1
# 7a1f3ca0 labeled as healthy_metal : 1
# 7a1f3e94 labeled as healthy_metal : 1
# 7a1f4ad8 labeled as healthy_metal : 1
# 7a1f4f38 labeled as healthy_metal : 1
# 7a1f5550 labeled as healthy_metal : 1
# 7a1f55be labeled as healthy_metal : 1
# 7a1f583e labeled as healthy_metal : 1
# 7a1f59ec labeled as healthy_metal : 1
# 7a1f5a50 labeled as healthy_metal : 1
# 7a1f60cc labeled as healthy_metal : 1
# 7a1f613a labeled as healthy_metal : 1
# 7a1f627a labeled as healthy_metal : 1
# 7a1f66ee labeled as healthy_metal : 1
# 7a1f6d06 labeled as healthy_metal : 1
# 7a1f7008 labeled as healthy_metal : 1
# 7a1f717a labeled as healthy_metal : 1
# 7a1f738c labeled as healthy_metal : 1
# 7a1f7530 labeled as healthy_metal : 1
# 7a1f7a12 labeled as healthy_metal : 1
# 7a1f7ada labeled as healthy_metal : 1
# 7a1f8368 labeled as healthy_metal : 1
# 7a1f960a labeled as healthy_metal : 1
# 7a1f9efc labeled as healthy_metal : 1
# 7a1f9ff6 labeled as healthy_metal : 1
# 7a1fa26c labeled as healthy_metal : 1
# 7a1fa3ac labeled as healthy_metal : 1
# 7a1fa758 labeled as healthy_metal : 1
# 7a1fb2f2 labeled as healthy_metal : 1
# 7a1fb43c labeled as healthy_metal : 1
# 7a1fbdec labeled as healthy_metal : 1
# 7a1fc0b2 labeled as healthy_metal : 1
# 7a1fcad0 labeled as healthy_metal : 1
# 7a1fd840 labeled as healthy_metal : 1
# 7a1fdec6 labeled as healthy_metal : 1
# 7a1fe0f6 labeled as healthy_metal : 1
# 7a1fe36c labeled as healthy_metal : 1
# 7a1fe7fe labeled as healthy_metal : 1
# 7a1fe86c labeled as healthy_metal : 1
# 7a1fea7e labeled as healthy_metal : 1
# 7a1febb4 labeled as healthy_metal : 1
# 7a1ff320 labeled as healthy_metal : 1
# 7a200126 labeled as healthy_metal : 1
# 7a20066c labeled as healthy_metal : 1
# 7a2008d8 labeled as healthy_metal : 1
# 7a200e1e labeled as healthy_metal : 1
# 7a2010e4 labeled as healthy_metal : 1
# 7a2011b6 labeled as healthy_metal : 1
# 7a201ab2 labeled as healthy_metal : 1
# 7a201f1c labeled as healthy_metal : 1
# 7a2022c8 labeled as healthy_metal : 1
# 7a20266a labeled as healthy_metal : 1
# 7a202732 labeled as healthy_metal : 1
# 7a202868 labeled as healthy_metal : 1
# 7a202b9c labeled as healthy_metal : 1
# 7a203088 labeled as healthy_metal : 1
# 7a203970 labeled as healthy_metal : 1
# 7a203c36 labeled as healthy_metal : 1
# 7a203dd0 labeled as healthy_metal : 1
# 7a20410e labeled as healthy_metal : 1
# 7a204172 labeled as healthy_metal : 1
# 7a204370 labeled as healthy_metal : 1
# 7a2043de labeled as healthy_metal : 1
# 7a204712 labeled as healthy_metal : 1
# 7a2049ec labeled as healthy_metal : 1
# 7a204a50 labeled as healthy_metal : 1
# 7a204cbc labeled as healthy_metal : 1
# 7a2052ca labeled as healthy_metal : 1
# 7a205b3a labeled as healthy_metal : 1
# 7a2060ee labeled as healthy_metal : 1
# 7a206a9e labeled as healthy_metal : 1
# 7a206c38 labeled as healthy_metal : 1
# 7a2072aa labeled as healthy_metal : 1
# 7a207516 labeled as healthy_metal : 1
# 7a20785e labeled as healthy_metal : 1
# 7a207d36 labeled as healthy_metal : 1
# 7a208074 labeled as healthy_metal : 1
# 7a2084e8 labeled as healthy_metal : 1
# 7a2085ba labeled as healthy_metal : 1
# 7a20861e labeled as healthy_metal : 1
# 7a208880 labeled as healthy_metal : 1
# 7a208bbe labeled as healthy_metal : 1
# 7a2093c0 labeled as healthy_metal : 1
# 7a20969a labeled as healthy_metal : 1
# 7a2096fe labeled as healthy_metal : 1
# 7a209834 labeled as healthy_metal : 1
# 7a209d0c labeled as healthy_metal : 1
# 7a20a112 labeled as healthy_metal : 1
# 7a20a1da labeled as healthy_metal : 1
# 7a20a57c labeled as healthy_metal : 1
# 7a20a64e labeled as healthy_metal : 1
# 7a20ab30 labeled as healthy_metal : 1
# 7a20aedc labeled as healthy_metal : 1
# 7a20b206 labeled as healthy_metal : 1
# 7a20b3a0 labeled as healthy_metal : 1
# 7a20b404 labeled as healthy_metal : 1
# 7a20b706 labeled as healthy_metal : 1
# 7a20c25a labeled as healthy_metal : 1
# 7a20c5d4 labeled as healthy_metal : 1
# 7a20c6a6 labeled as healthy_metal : 1
# 7a20c980 labeled as healthy_metal : 1
# 7a20e2b2 labeled as healthy_metal : 1
# 7a20e4ba labeled as healthy_metal : 1
# 7a20eed8 labeled as healthy_metal : 1
# 7a20f6f8 labeled as healthy_metal : 1
# 7a20f838 labeled as healthy_metal : 1
# 7a20fbe4 labeled as healthy_metal : 1
# 7a20ff9a labeled as healthy_metal : 1
# 7a2100d0 labeled as healthy_metal : 1
# 7a210616 labeled as healthy_metal : 1
# 7a2108f0 labeled as healthy_metal : 1
# 7a221eb6 labeled as healthy_metal : 1
# 7a222122 labeled as healthy_metal : 1
# 7a222ee2 labeled as healthy_metal : 1
# 7a223086 labeled as healthy_metal : 1
# 7a223630 labeled as healthy_metal : 1
# 7a224134 labeled as healthy_metal : 1
# 7a2241a2 labeled as healthy_metal : 1
# 7a224418 labeled as healthy_metal : 1
# 7a22476a labeled as healthy_metal : 1
# 7a224b5c labeled as healthy_metal : 1
# 7a225a98 labeled as healthy_metal : 1
# 7a225b60 labeled as healthy_metal : 1
# 7a226524 labeled as healthy_metal : 1
# 7a226a10 labeled as healthy_metal : 1
# 7a227eec labeled as healthy_metal : 1
# 7a228310 labeled as healthy_metal : 1
# 7a22903a labeled as healthy_metal : 1
# 7a22910c labeled as healthy_metal : 1
# 7a229850 labeled as healthy_metal : 1
# 7a229d8c labeled as healthy_metal : 1
# 7a229ecc labeled as healthy_metal : 1
# 7a22a20a labeled as healthy_metal : 1
# 7a22a3ae labeled as healthy_metal : 1
# 7a22a480 labeled as healthy_metal : 1
# 7a22a61a labeled as healthy_metal : 1
# 7a22a87c labeled as healthy_metal : 1
# 7a22aade labeled as healthy_metal : 1
# 7a22ac1e labeled as healthy_metal : 1
# 7a22afb6 labeled as healthy_metal : 1
# 7a22bac4 labeled as healthy_metal : 1
# 7a22bba0 labeled as healthy_metal : 1
# 7a22bede labeled as healthy_metal : 1
# 7a22c014 labeled as healthy_metal : 1
# 7a22c0e6 labeled as healthy_metal : 1
# 7a22c154 labeled as healthy_metal : 1
# 7a22d040 labeled as healthy_metal : 1
# 7a22d874 labeled as healthy_metal : 1
# 7a22dfa4 labeled as healthy_metal : 1
# 7a22e86e labeled as healthy_metal : 1
# 7a22eb66 labeled as healthy_metal : 1
# 7a22f00c labeled as healthy_metal : 1
# 7a22f0de labeled as healthy_metal : 1
# 7a22f5f2 labeled as healthy_metal : 1
# 7a22fb74 labeled as healthy_metal : 1
# 7a22fd22 labeled as healthy_metal : 1
# 7a22ffc0 labeled as healthy_metal : 1
# 7a230560 labeled as healthy_metal : 1
# 7a2305ce labeled as healthy_metal : 1
# 7a2308d0 labeled as healthy_metal : 1
# 7a230d12 labeled as healthy_metal : 1
# 7a230d80 labeled as healthy_metal : 1
# 7a2315f0 labeled as healthy_metal : 1
# 7a231730 labeled as healthy_metal : 1
# 7a23180c labeled as healthy_metal : 1
# 7a231d3e labeled as healthy_metal : 1
# 7a23263a labeled as healthy_metal : 1
# 7a232b26 labeled as healthy_metal : 1
# 7a232b94 labeled as healthy_metal : 1
# 7a232ea0 labeled as healthy_metal : 1
# 7a2332ec labeled as healthy_metal : 1
# 7a233b2a labeled as healthy_metal : 1
# 7a234b42 labeled as healthy_metal : 1
# 7a23502e labeled as healthy_metal : 1
# 7a235b0a labeled as healthy_metal : 1
# 7a235c7c labeled as healthy_metal : 1
# 7a2363e8 labeled as healthy_metal : 1
# 7a236834 labeled as healthy_metal : 1
# 7a238742 labeled as healthy_metal : 1
# 7a238db4 labeled as healthy_metal : 1
# 7a238fda labeled as healthy_metal : 1
# 7a23925a labeled as healthy_metal : 1
# 7a250770 labeled as healthy_metal : 1
# 7a251512 labeled as healthy_metal : 1
# 7a251800 labeled as healthy_metal : 1
# 7a251de6 labeled as healthy_metal : 1
# 7a251e4a labeled as healthy_metal : 1
# 7a2526ba labeled as healthy_metal : 1
# 7a252ca0 labeled as healthy_metal : 1
# 7a252f98 labeled as healthy_metal : 1
# 7a253074 labeled as healthy_metal : 1
# 7a253362 labeled as healthy_metal : 1
# 7a253c90 labeled as healthy_metal : 1
# 7a253cfe labeled as healthy_metal : 1
# 7a253f1a labeled as healthy_metal : 1
# 7a254a00 labeled as healthy_metal : 1
# 7a254c1c labeled as healthy_metal : 1
# 7a254dc0 labeled as healthy_metal : 1
# 7a254e2e labeled as healthy_metal : 1
# 7a254f00 labeled as healthy_metal : 1
# 7a254fdc labeled as healthy_metal : 1
# 7a255252 labeled as healthy_metal : 1
# 7a25546e labeled as healthy_metal : 1
# 7a255540 labeled as healthy_metal : 1
# 7a255748 labeled as healthy_metal : 1
# 7a255afe labeled as healthy_metal : 1
# 7a255c34 labeled as healthy_metal : 1
# 7a256350 labeled as healthy_metal : 1
# 7a256bac labeled as healthy_metal : 1
# 7a2571f6 labeled as healthy_metal : 1
# 7a25725a labeled as healthy_metal : 1
# 7a257412 labeled as healthy_metal : 1
# 7a257764 labeled as healthy_metal : 1
# 7a257bf6 labeled as healthy_metal : 1
# 7a258326 labeled as healthy_metal : 1
# 7a2587c2 labeled as healthy_metal : 1
# 7a2591c2 labeled as healthy_metal : 1
# 7a2595f0 labeled as healthy_metal : 1
# 7a25a284 labeled as healthy_metal : 1
# 7a25a93c labeled as healthy_metal : 1
# 7a25b044 labeled as healthy_metal : 1
# 7a25b1f2 labeled as healthy_metal : 1
# 7a25b76a labeled as healthy_metal : 1
# 7a25bc06 labeled as healthy_metal : 1
# 7a25bfd0 labeled as healthy_metal : 1
# 7a25c1ec labeled as healthy_metal : 1
# 7a25c46c labeled as healthy_metal : 1
# 7a25c8ae labeled as healthy_metal : 1
# 7a25d04c labeled as healthy_metal : 1
# 7a25d560 labeled as healthy_metal : 1
# 7a25d772 labeled as healthy_metal : 1
# 7a25e78a labeled as healthy_metal : 1
# 7a25e8ca labeled as healthy_metal : 1
# 7a25eaf0 labeled as healthy_metal : 1
# 7a25ec94 labeled as healthy_metal : 1
# 7a25ed02 labeled as healthy_metal : 1
# 7a25f1f8 labeled as healthy_metal : 1
# 7a25f2ca labeled as healthy_metal : 1
# 7a25f824 labeled as healthy_metal : 1
# 7a25f964 labeled as healthy_metal : 1
# 7a2600d0 labeled as healthy_metal : 1
# 7a2601a2 labeled as healthy_metal : 1
# 7a2610ac labeled as healthy_metal : 1
# 7a261188 labeled as healthy_metal : 1
# 7a261aca labeled as healthy_metal : 1
# 7a261b4c labeled as healthy_metal : 1
# 7a262010 labeled as healthy_metal : 1
# 7a2621d2 labeled as healthy_metal : 1
# 7a26245c labeled as healthy_metal : 1
# 7a262826 labeled as healthy_metal : 1
# 7a2629de labeled as healthy_metal : 1
# 7a262c04 labeled as healthy_metal : 1
# 7a263032 labeled as healthy_metal : 1
# 7a263172 labeled as healthy_metal : 1
# 7a263604 labeled as healthy_metal : 1
# 7a2637a8 labeled as healthy_metal : 1
# 7a263956 labeled as healthy_metal : 1
# 7a263ca8 labeled as healthy_metal : 1
# 7a263d0c labeled as healthy_metal : 1
# 7a263f28 labeled as healthy_metal : 1
# 7a26405e labeled as healthy_metal : 1
# 7a2640cc labeled as healthy_metal : 1
# 7a26446e labeled as healthy_metal : 1
# 7a264946 labeled as healthy_metal : 1
# 7a2653c8 labeled as healthy_metal : 1
# 7a265b66 labeled as healthy_metal : 1
# 7a265eb8 labeled as healthy_metal : 1
# 7a2665ca labeled as healthy_metal : 1
# 7a266dae labeled as healthy_metal : 1
# 7a267038 labeled as healthy_metal : 1
# 7a267254 labeled as healthy_metal : 1
# 7a267402 labeled as healthy_metal : 1
# 7a267844 labeled as healthy_metal : 1
# 7a26797a labeled as healthy_metal : 1
# 7a267ac4 labeled as healthy_metal : 1
# 7a267c04 labeled as healthy_metal : 1
# 7a267e2a labeled as healthy_metal : 1
# 7a267f6a labeled as healthy_metal : 1
# 7a268398 labeled as healthy_metal : 1
# 7a2688a2 labeled as healthy_metal : 1
# 7a268974 labeled as healthy_metal : 1
# 7a268b22 labeled as healthy_metal : 1
# 7a26955e labeled as healthy_metal : 1
# 7a269d88 labeled as healthy_metal : 1
# 7a26b408 labeled as healthy_metal : 1
# 7a26b4e4 labeled as healthy_metal : 1
# 7a26b76e labeled as healthy_metal : 1
# 7a26bca0 labeled as healthy_metal : 1
# 7a26bd36 labeled as healthy_metal : 1
# 7a26c10a labeled as healthy_metal : 1
# 7a26ccfe labeled as healthy_metal : 1
# 7a26d5a0 labeled as healthy_metal : 1
# 7a26d9c4 labeled as healthy_metal : 1
# 7a26db0e labeled as healthy_metal : 1
# 7a26dcbc labeled as healthy_metal : 1
# 7a26dd2a labeled as healthy_metal : 1
# 7a26de6a labeled as healthy_metal : 1
# 7a26ec7a labeled as healthy_metal : 1
# 7a26ef68 labeled as healthy_metal : 1
# 7a26f670 labeled as healthy_metal : 1
# 7a270250 labeled as healthy_metal : 1
# 7a2703fe labeled as healthy_metal : 1
# 7a270ab6 labeled as healthy_metal : 1
# 7a270c64 labeled as healthy_metal : 1
# 7a270ee4 labeled as healthy_metal : 1
# 7a271164 labeled as healthy_metal : 1
# 7a271b5a labeled as healthy_metal : 1
# 7a271bc8 labeled as healthy_metal : 1
# 7a271c36 labeled as healthy_metal : 1
# 7a272258 labeled as healthy_metal : 1
# 7a272e38 labeled as healthy_metal : 1
# 7a272f6e labeled as healthy_metal : 1
# 7a2730ae labeled as healthy_metal : 1
# 7a2738d8 labeled as healthy_metal : 1
# 7a273f18 labeled as healthy_metal : 1
# 7a273f86 labeled as healthy_metal : 1
# 7a2749c2 labeled as healthy_metal : 1
# 7a274d0a labeled as healthy_metal : 1
# 7a2752e6 labeled as healthy_metal : 1
# 7a27593a labeled as healthy_metal : 1
# 7a2759a8 labeled as healthy_metal : 1
# 7a275e6c labeled as healthy_metal : 1
# 7a276ae2 labeled as healthy_metal : 1
# 7a29b1e4 labeled as healthy_metal : 1
# 7a29bd10 labeled as healthy_metal : 1
# 7a29bdec labeled as healthy_metal : 1
# 7a29c1b6 labeled as healthy_metal : 1
# 7a29c2f6 labeled as healthy_metal : 1
# 7a29c5e4 labeled as healthy_metal : 1
# 7a29d05c labeled as healthy_metal : 1
# 7a29d0e8 labeled as healthy_metal : 1
# 7a29d2c8 labeled as healthy_metal : 1
# 7a29e1c8 labeled as healthy_metal : 1
# 7a29e5b0 labeled as healthy_metal : 1
# 7a29e6c8 labeled as healthy_metal : 1
# 7a29ebb4 labeled as healthy_metal : 1
# 7a29ec90 labeled as healthy_metal : 1
# 7a29f42e labeled as healthy_metal : 1
# 7a29f64a labeled as healthy_metal : 1
# 7a29f9b0 labeled as healthy_metal : 1
# 7a29fa1e labeled as healthy_metal : 1
# 7a29fc3a labeled as healthy_metal : 1
# 7a2a0144 labeled as healthy_metal : 1
# 7a2a0c66 labeled as healthy_metal : 1
# 7a2a122e labeled as healthy_metal : 1
# 7a2a15f8 labeled as healthy_metal : 1
# 7a2a1878 labeled as healthy_metal : 1
# 7a2a20ac labeled as healthy_metal : 1
# 7a2a249e labeled as healthy_metal : 1
# 7a2a2a16 labeled as healthy_metal : 1
# 7a2a3146 labeled as healthy_metal : 1
# 7a2a32f4 labeled as healthy_metal : 1
# 7a2a3ac4 labeled as healthy_metal : 1
# 7a2a3ce0 labeled as healthy_metal : 1
# 7a2a4a28 labeled as healthy_metal : 1
# 7a2a5266 labeled as healthy_metal : 1
# 7a2a554a labeled as healthy_metal : 1
# 7a2a56bc labeled as healthy_metal : 1
# 7a2a5ac2 labeled as healthy_metal : 1
# 7a2a6378 labeled as healthy_metal : 1
# 7a2a6774 labeled as healthy_metal : 1
# 7a2a6832 labeled as healthy_metal : 1
# 7a2a68e6 labeled as healthy_metal : 1
# 7a2a7a70 labeled as healthy_metal : 1
# 7a2a7b24 labeled as healthy_metal : 1
# 7a2a868c labeled as healthy_metal : 1
# 7a2a8768 labeled as healthy_metal : 1
# 7a2a89e8 labeled as healthy_metal : 1
# 7a2a8aa6 labeled as healthy_metal : 1
# 7a2a9442 labeled as healthy_metal : 1
# 7a2aa248 labeled as healthy_metal : 1
# 7a2aa68a labeled as healthy_metal : 1
# 7a2aa982 labeled as healthy_metal : 1
# 7a2aaa5e labeled as healthy_metal : 1
# 7a2aac98 labeled as healthy_metal : 1
# 7a2ab4e0 labeled as healthy_metal : 1
# 7a2ac142 labeled as healthy_metal : 1
# 7a2ad362 labeled as healthy_metal : 1
# 7a2ad718 labeled as healthy_metal : 1
# 7a2ae97e labeled as healthy_metal : 1
# 7a2af1d0 labeled as healthy_metal : 1
# 7a2af7ac labeled as healthy_metal : 1
# 7a2b100c labeled as healthy_metal : 1
# 7a2b1232 labeled as healthy_metal : 1
# 7a2b185e labeled as healthy_metal : 1
# 7a2b20ce labeled as healthy_metal : 1
# 7a2b31cc labeled as healthy_metal : 1
# 7a2b32d0 labeled as healthy_metal : 1
# 7a2b3cbc labeled as healthy_metal : 1
# 7a2b3e38 labeled as healthy_metal : 1
# 7a2b4112 labeled as healthy_metal : 1
# 7a2b4a2c labeled as healthy_metal : 1
# 7a2b4da6 labeled as healthy_metal : 1
# 7a2b4f0e labeled as healthy_metal : 1
# 7a2b4fcc labeled as healthy_metal : 1
# 7a2b59f4 labeled as healthy_metal : 1
# 7a2b5c1a labeled as healthy_metal : 1
# 7a2b5fe4 labeled as healthy_metal : 1
# 7a2b62aa labeled as healthy_metal : 1
# 7a2b6340 labeled as healthy_metal : 1
# 7a2b63e0 labeled as healthy_metal : 1
# 7a2b748e labeled as healthy_metal : 1
# 7a2b7506 labeled as healthy_metal : 1
# 7a2b7ed4 labeled as healthy_metal : 1
# 7a2b7f4c labeled as healthy_metal : 1
# 7a2b8d5c labeled as healthy_metal : 1
# 7a2b8fe6 labeled as healthy_metal : 1
# 7a2b94aa labeled as healthy_metal : 1
# 7a2b9f7c labeled as healthy_metal : 1
# 7a2ba3c8 labeled as healthy_metal : 1
# 7a2ba5e4 labeled as healthy_metal : 1
# 7a2bacd8 labeled as healthy_metal : 1
# 7a2bb0d4 labeled as healthy_metal : 1
# 7a2bb6a6 labeled as healthy_metal : 1
# 7a2bbcf0 labeled as healthy_metal : 1
# 7a2bc0b0 labeled as healthy_metal : 1
# 7a2bc18c labeled as healthy_metal : 1
# 7a2bc47a labeled as healthy_metal : 1
# 7a2bdb5e labeled as healthy_metal : 1
# 7a2be568 labeled as healthy_metal : 1
# 7a2befb8 labeled as healthy_metal : 1
# 7a2bfbca labeled as healthy_metal : 1
# 7a2c0188 labeled as healthy_metal : 1
# 7a2c0674 labeled as healthy_metal : 1
# 7a2c0e8a labeled as healthy_metal : 1
# 7a2c0ef8 labeled as healthy_metal : 1
# 7a2c1394 labeled as healthy_metal : 1
# 7a2c16e6 labeled as healthy_metal : 1
# 7a2c285c labeled as healthy_metal : 1
# 7a2c2992 labeled as healthy_metal : 1
# 7a2c2a64 labeled as healthy_metal : 1
# 7a2c2c12 labeled as healthy_metal : 1
# 7a2c2cee labeled as healthy_metal : 1
# 7a2c2dc0 labeled as healthy_metal : 1
# 7a2c2e2e labeled as healthy_metal : 1
# 7a2c325c labeled as healthy_metal : 1
# 7a2c3d10 labeled as healthy_metal : 1
# 7a2c4260 labeled as healthy_metal : 1
# 7a2c447c labeled as healthy_metal : 1
# 7a2c4f30 labeled as healthy_metal : 1
# 7a2c53b8 labeled as healthy_metal : 1
# 7a2c5912 labeled as healthy_metal : 1
# 7a2c59e4 labeled as healthy_metal : 1
# 7a2c5df4 labeled as healthy_metal : 1
# 7a2c60d8 labeled as healthy_metal : 1
# 7a2c62ea labeled as healthy_metal : 1
# 7a2c63bc labeled as healthy_metal : 1
# 7a2c6984 labeled as healthy_metal : 1
# 7a2c715e labeled as healthy_metal : 1
# 7a2c7302 labeled as healthy_metal : 1
# 7a2c7b36 labeled as healthy_metal : 1
# 7a2c82c0 labeled as healthy_metal : 1
# 7a2c8446 labeled as healthy_metal : 1
# 7a2c87fc labeled as healthy_metal : 1
# 7a2c8c66 labeled as healthy_metal : 1
# 7a2c8e1e labeled as healthy_metal : 1
# 7a2c9116 labeled as healthy_metal : 1
# 7a2c91e8 labeled as healthy_metal : 1
# 7a2c92ba labeled as healthy_metal : 1
# 7a2c9468 labeled as healthy_metal : 1
# 7a2c953a labeled as healthy_metal : 1
# 7a2c9684 labeled as healthy_metal : 1
# 7a2c97ba labeled as healthy_metal : 1
# 7a2c9832 labeled as healthy_metal : 1
# 7a2c9ee0 labeled as healthy_metal : 1
# 7a2c9fb2 labeled as healthy_metal : 1
# 7a2ca020 labeled as healthy_metal : 1
# 7a2ca598 labeled as healthy_metal : 1
# 7a2caa16 labeled as healthy_metal : 1
# 7a2caf16 labeled as healthy_metal : 1
# 7a2cb556 labeled as healthy_metal : 1
# 7a2cb628 labeled as healthy_metal : 1
# 7a2cbc04 labeled as healthy_metal : 1
# 7a2cc532 labeled as healthy_metal : 1
# 7a2cc60e labeled as healthy_metal : 1
# 7a2cc71c labeled as healthy_metal : 1
# 7a2cc992 labeled as healthy_metal : 1
# 7a2ccb4a labeled as healthy_metal : 1
# 7a2ccbb8 labeled as healthy_metal : 1
# 7a2ccfd2 labeled as healthy_metal : 1
# 7a2cd252 labeled as healthy_metal : 1
# 7a2cd40a labeled as healthy_metal : 1
# 7a2cd46e labeled as healthy_metal : 1
# 7a2cd838 labeled as healthy_metal : 1
# 7a2cd9e6 labeled as healthy_metal : 1
# 7a2cdf54 labeled as healthy_metal : 1
# 7a2ce454 labeled as healthy_metal : 1
# 7a2ce8f0 labeled as healthy_metal : 1
# 7a2cea9e labeled as healthy_metal : 1
# 7a2cedf0 labeled as healthy_metal : 1
# 7a2cf142 labeled as healthy_metal : 1
# 7a2cf94e labeled as healthy_metal : 1
# 7a2cfcaa labeled as healthy_metal : 1
# 7a2d00e2 labeled as healthy_metal : 1
# 7a2d0222 labeled as healthy_metal : 1
# 7a2d0844 labeled as healthy_metal : 1
# 7a2d0ba0 labeled as healthy_metal : 1
# 7a2d0c7c labeled as healthy_metal : 1
# 7a2d0d4e labeled as healthy_metal : 1
# 7a2d0dbc labeled as healthy_metal : 1
# 7a2d0e2a labeled as healthy_metal : 1
# 7a2d1384 labeled as healthy_metal : 1
# 7a2d13f2 labeled as healthy_metal : 1
# 7a2d2004 labeled as healthy_metal : 1
# 7a2d2572 labeled as healthy_metal : 1
# 7a2d2932 labeled as healthy_metal : 1
# 7a2d2f04 labeled as healthy_metal : 1
# 7a2d3896 labeled as healthy_metal : 1
# 7a2d3e72 labeled as healthy_metal : 1
# 7a2d3f4e labeled as healthy_metal : 1
# 7a2d46ce labeled as healthy_metal : 1
# 7a2d487c labeled as healthy_metal : 1
# 7a2d55ce labeled as healthy_metal : 1
# 7a2d56a0 labeled as healthy_metal : 1
# 7a2d57ea labeled as healthy_metal : 1
# 7a2d592a labeled as healthy_metal : 1
# 7a2d5ce0 labeled as healthy_metal : 1
# 7a2d5e20 labeled as healthy_metal : 1
# 7a2d6032 labeled as healthy_metal : 1
# 7a2d64ba labeled as healthy_metal : 1
# 7a2d658c labeled as healthy_metal : 1
# 7a2d6668 labeled as healthy_metal : 1
# 7a2d7266 labeled as healthy_metal : 1
# 7a2d739c labeled as healthy_metal : 1
# 7a2d746e labeled as healthy_metal : 1
# 7a2d7892 labeled as healthy_metal : 1
# 7a2d78f6 labeled as healthy_metal : 1
# 7a2d7a9a labeled as healthy_metal : 1
# 7a2d7cac labeled as healthy_metal : 1
# 7a2d8206 labeled as healthy_metal : 1
# 7a2d8418 labeled as healthy_metal : 1
# 7a2d84ea labeled as healthy_metal : 1
# 7a2d868e labeled as healthy_metal : 1
# 7a2d8832 labeled as healthy_metal : 1
# 7a2d8972 labeled as healthy_metal : 1
# 7a2d8f58 labeled as healthy_metal : 1
# 7a2d9fe8 labeled as healthy_metal : 1
# 7a2da0c4 labeled as healthy_metal : 1
# 7a2da8c6 labeled as healthy_metal : 1
# 7a2dadda labeled as healthy_metal : 1
# 7a2db41a labeled as healthy_metal : 1
# 7a2db640 labeled as healthy_metal : 1
# 7a2dbb40 labeled as healthy_metal : 1
# 7a2dc054 labeled as healthy_metal : 1
# 7a2dc4f0 labeled as healthy_metal : 1
# 7a2dcdce labeled as healthy_metal : 1
# 7a2dce3c labeled as healthy_metal : 1
# 7a2dd58a labeled as healthy_metal : 1
# 7a2dd65c labeled as healthy_metal : 1
# 7a2dd878 labeled as healthy_metal : 1
# 7a2ddb66 labeled as healthy_metal : 1
# 7a2ddbe8 labeled as healthy_metal : 1
# 7a2de160 labeled as healthy_metal : 1
# 7a2de1ce labeled as healthy_metal : 1
# 7a2de37c labeled as healthy_metal : 1
# 7a2de458 labeled as healthy_metal : 1
# 7a2de746 labeled as healthy_metal : 1
# 7a2de9da labeled as healthy_metal : 1
# 7a2dec00 labeled as healthy_metal : 1
# 7a2deeee labeled as healthy_metal : 1
# 7a2df66e labeled as healthy_metal : 1
# 7a2e01a4 labeled as healthy_metal : 1
# 7a2e0488 labeled as healthy_metal : 1
# 7a2e091a labeled as healthy_metal : 1
# 7a2e0d34 labeled as healthy_metal : 1
# 7a2e1158 labeled as healthy_metal : 1
# 7a2e1374 labeled as healthy_metal : 1
# 7a2e14b4 labeled as healthy_metal : 1
# 7a2e1fc2 labeled as healthy_metal : 1
# 7a2e21de labeled as healthy_metal : 1
# 7a2e231e labeled as healthy_metal : 1
# 7a2e24cc labeled as healthy_metal : 1
# 7a2e2616 labeled as healthy_metal : 1
# 7a2e2968 labeled as healthy_metal : 1
# 7a2e2fa8 labeled as healthy_metal : 1
# 7a2e343a labeled as healthy_metal : 1
# 7a2e34a8 labeled as healthy_metal : 1
# 7a2e3a0c labeled as healthy_metal : 1
# 7a2e3ade labeled as healthy_metal : 1
# 7a2e3b4c labeled as healthy_metal : 1
# 7a2e47d6 labeled as healthy_metal : 1
# ...
# 7a3ae41e labeled as irregular_metal : 3
# 7a3ae5cc labeled as irregular_metal : 3
# 7a3aea68 labeled as irregular_metal : 3
# 7a3af436 labeled as irregular_metal : 3
# 7a3af652 labeled as irregular_metal : 3
# 7a3af9ae labeled as irregular_metal : 3
# 7a3afaf8 labeled as irregular_metal : 3
# 7a3afbca labeled as irregular_metal : 3
# 7a3afc9c labeled as irregular_metal : 3
# 7a3b0458 labeled as irregular_metal : 3
# 7a3b0746 labeled as irregular_metal : 3
# 7a3b0aa2 labeled as irregular_metal : 3
# 7a3b0d5e labeled as irregular_metal : 3
# 7a3b0f7a labeled as irregular_metal : 3
# 7a3b1344 labeled as irregular_metal : 3
# 7a3b1b32 labeled as irregular_metal : 3
# 7a3b21ea labeled as irregular_metal : 3
# 7a3b26f4 labeled as irregular_metal : 3
# 7a3b27c6 labeled as irregular_metal : 3
# 7a3b2bea labeled as irregular_metal : 3
# 7a3b2d8e labeled as irregular_metal : 3
# 7a3b30ea labeled as irregular_metal : 3
# 7a3b4134 labeled as irregular_metal : 3
# 7a3b4210 labeled as irregular_metal : 3
# 7a3b4490 labeled as irregular_metal : 3
# 7a3b49ea labeled as irregular_metal : 3
# 7a3b54a8 labeled as irregular_metal : 3
# 7a3b5930 labeled as irregular_metal : 3
# 7a3b5f02 labeled as irregular_metal : 3
# 7a3b625e labeled as irregular_metal : 3
# 7a3b64d4 labeled as irregular_metal : 3
# 7a3b674a labeled as irregular_metal : 3
# 7a3b6e52 labeled as irregular_metal : 3
# 7a3b8e14 labeled as irregular_metal : 3
# 7a3b95ee labeled as irregular_metal : 3
# 7a3b9be8 labeled as irregular_metal : 3
# 7a3ba71e labeled as irregular_metal : 3
# 7a3ba99e labeled as irregular_metal : 3
# 7a3bb114 labeled as irregular_metal : 3
# 7a3bb74a labeled as irregular_metal : 3
# 7a3bb7ae labeled as irregular_metal : 3
# 7a3bbb00 labeled as irregular_metal : 3
# 7a3bc6b8 labeled as irregular_metal : 3
# 7a3bcd02 labeled as irregular_metal : 3
# 7a3bdf18 labeled as irregular_metal : 3
# 7a3be74c labeled as irregular_metal : 3
# 7a3be968 labeled as irregular_metal : 3
# 7a3bef8a labeled as irregular_metal : 3
# 7a3beff8 labeled as irregular_metal : 3
# 7a3bfba6 labeled as irregular_metal : 3
# 7a3bfc78 labeled as irregular_metal : 3
# 7a3c0876 labeled as irregular_metal : 3
# 7a3c27de labeled as irregular_metal : 3
# 7a3c34c2 labeled as irregular_metal : 3
# 7a3c3d6e labeled as irregular_metal : 3
# 7a3c40c0 labeled as irregular_metal : 3
# 7a3c44da labeled as irregular_metal : 3
# 7a3c484a labeled as irregular_metal : 3
# 7a3c4e8a labeled as irregular_metal : 3
# 7a3c4f66 labeled as irregular_metal : 3
# 7a3c5614 labeled as irregular_metal : 3
# 7a3c574a labeled as irregular_metal : 3
# 7a3c614a labeled as irregular_metal : 3
# 7a3c61b8 labeled as irregular_metal : 3
# 7a3c6226 labeled as irregular_metal : 3
# 7a3c651e labeled as irregular_metal : 3
# 7a3c6870 labeled as irregular_metal : 3
# 7a3c6bcc labeled as irregular_metal : 3
# 7a3c7054 labeled as irregular_metal : 3
# 7a3c72d4 labeled as irregular_metal : 3
# 7a3c7694 labeled as irregular_metal : 3
# 7a3c7ba8 labeled as irregular_metal : 3
# 7a3c8e68 labeled as irregular_metal : 3
# 7a3ca1be labeled as irregular_metal : 3
# 7a3ca646 labeled as irregular_metal : 3
# 7a3ca9a2 labeled as irregular_metal : 3
# 7a3ccb26 labeled as irregular_metal : 3
# 7a3ccedc labeled as irregular_metal : 3
# 7a3ccf4a labeled as irregular_metal : 3
# 7a3cd378 labeled as irregular_metal : 3
# 7a3cd72e labeled as irregular_metal : 3
# 7a3cd86e labeled as irregular_metal : 3
# 7a3cdbca labeled as irregular_metal : 3
# 7a3ce610 labeled as irregular_metal : 3
# 7a3ce7be labeled as irregular_metal : 3
# 7a3cf2e0 labeled as irregular_metal : 3
# 7a3cf48e labeled as irregular_metal : 3
# 7a3cf920 labeled as irregular_metal : 3
# 7a3cfede labeled as irregular_metal : 3
# 7a3d0c80 labeled as irregular_metal : 3
# 7a3d0fd2 labeled as irregular_metal : 3
# 7a3d125c labeled as irregular_metal : 3
# 7a3d1a9a labeled as irregular_metal : 3
# 7a3d204e labeled as irregular_metal : 3
# 7a3d23a0 labeled as irregular_metal : 3
# 7a3d2828 labeled as irregular_metal : 3
# 7a3d3278 labeled as irregular_metal : 3
# 7a3d40e2 labeled as irregular_metal : 3
# 7a3d556e labeled as irregular_metal : 3
# 7a3d571c labeled as irregular_metal : 3
# 7a3d5c08 labeled as irregular_metal : 3
# 7a3d5e74 labeled as irregular_metal : 3
# 7a3d5ee2 labeled as irregular_metal : 3
# 7a3d6504 labeled as irregular_metal : 3
# 7a3d691e labeled as irregular_metal : 3
# 7a3d797c labeled as irregular_metal : 3
# 7a3d7ab2 labeled as irregular_metal : 3
# 7a3d819c labeled as irregular_metal : 3
# 7a3d95ba labeled as irregular_metal : 3
# 7a3da8c0 labeled as irregular_metal : 3
# 7a3da92e labeled as irregular_metal : 3
# 7a3dac6c labeled as irregular_metal : 3
# 7a3dafb4 labeled as irregular_metal : 3
# 7a3db856 labeled as irregular_metal : 3
# 7a3dbd42 labeled as irregular_metal : 3
# 7a3dc224 labeled as irregular_metal : 3
# 7a3dc8b4 labeled as irregular_metal : 3
# 7a3dd1ba labeled as irregular_metal : 3
# 7a3dde12 labeled as irregular_metal : 3
# 7a3ddee4 labeled as irregular_metal : 3
# 7a3df492 labeled as irregular_metal : 3
# 7a3df8a2 labeled as irregular_metal : 3
# 7a3dfaaa labeled as irregular_metal : 3
# 7a3dfb7c labeled as irregular_metal : 3
# 7a3e039c labeled as irregular_metal : 3
# 7a3e0716 labeled as irregular_metal : 3
# 7a3e0928 labeled as irregular_metal : 3
# 7a3e0acc labeled as irregular_metal : 3
# 7a3e0c70 labeled as irregular_metal : 3
# 7a3e1c60 labeled as irregular_metal : 3
# 7a3e1e72 labeled as irregular_metal : 3
# 7a3e21b0 labeled as irregular_metal : 3
# 7a3e2912 labeled as irregular_metal : 3
# 7a3e2ab6 labeled as irregular_metal : 3
# 7a3e2b88 labeled as irregular_metal : 3
# 7a3e2bec labeled as irregular_metal : 3
# 7a3e35d8 labeled as irregular_metal : 3
# 7a3e38b2 labeled as irregular_metal : 3
# 7a3e44f6 labeled as irregular_metal : 3
# 7a3e53b0 labeled as irregular_metal : 3
# 7a3e54f0 labeled as irregular_metal : 3
# 7a3e5766 labeled as irregular_metal : 3
# 7a3e5838 labeled as irregular_metal : 3
# 7a3e6206 labeled as irregular_metal : 3
# 7a3e6788 labeled as irregular_metal : 3
# 7a3e699a labeled as irregular_metal : 3
# 7a3e6f4e labeled as irregular_metal : 3
# 7a3e708e labeled as irregular_metal : 3
# 7a3e7728 labeled as irregular_metal : 3
# 7a3e7930 labeled as irregular_metal : 3
# 7a3e7f16 labeled as irregular_metal : 3
# 7a3e92f8 labeled as irregular_metal : 3
# 7a3e9708 labeled as irregular_metal : 3
# 7a3ea1c6 labeled as irregular_metal : 3
# 7a3ea446 labeled as irregular_metal : 3
# 7a3ea6bc labeled as irregular_metal : 3
# 7a3ea72a labeled as irregular_metal : 3
# 7a3eadba labeled as irregular_metal : 3
# 7a3eb314 labeled as irregular_metal : 3
# 7a3eb51c labeled as irregular_metal : 3
# 7a3eb5ee labeled as irregular_metal : 3
# 7a3eb79c labeled as irregular_metal : 3
# 7a3ecd86 labeled as irregular_metal : 3
# 7a3ece58 labeled as irregular_metal : 3
# 7a3ecebc labeled as irregular_metal : 3
# 7a3ed1a0 labeled as irregular_metal : 3
# 7a3ed768 labeled as irregular_metal : 3
# 7a3ed9de labeled as irregular_metal : 3
# 7a3edb8c labeled as irregular_metal : 3
# 7a3efe78 labeled as irregular_metal : 3
# 7a3f0940 labeled as irregular_metal : 3
# 7a3f0c88 labeled as irregular_metal : 3
# 7a3f13f4 labeled as irregular_metal : 3
# 7a3f26f0 labeled as irregular_metal : 3
# 7a3f32bc labeled as irregular_metal : 3
# 7a3f34ec labeled as irregular_metal : 3
# 7a3f3564 labeled as irregular_metal : 3
# 7a3f3730 labeled as irregular_metal : 3
# 7a3f3df2 labeled as irregular_metal : 3
# 7a3f3e60 labeled as irregular_metal : 3
# 7a3f4b6c labeled as irregular_metal : 3
# 7a3f4f36 labeled as irregular_metal : 3
# 7a3f581e labeled as irregular_metal : 3
# 7a3f5c56 labeled as irregular_metal : 3
# 7a3f7efc labeled as irregular_metal : 3
# 7a3f8d20 labeled as irregular_metal : 3
# 7a3f8d8e labeled as irregular_metal : 3
# 7a3f9856 labeled as irregular_metal : 3
# 7a3fb4bc labeled as irregular_metal : 3
# 7a3fb962 labeled as irregular_metal : 3
# 7a3fc740 labeled as irregular_metal : 3
# 7a3fda78 labeled as irregular_metal : 3
# 7a3fdae6 labeled as irregular_metal : 3
# 7a3fdbc2 labeled as irregular_metal : 3
# 7a3fdc26 labeled as irregular_metal : 3
# 7a3fdf96 labeled as irregular_metal : 3
# 7a3feab8 labeled as irregular_metal : 3
# 7a3fefd6 labeled as irregular_metal : 3
# 7a40019c labeled as irregular_metal : 3
# 7a4005d4 labeled as irregular_metal : 3
# 7a400a02 labeled as irregular_metal : 3
# 7a400bba labeled as irregular_metal : 3
# 7a400ea8 labeled as irregular_metal : 3
# 7a401196 labeled as irregular_metal : 3
# 7a402bb8 labeled as irregular_metal : 3
# 7a4032de labeled as irregular_metal : 3
# 7a4033ba labeled as irregular_metal : 3
# 7a403928 labeled as irregular_metal : 3
# 7a403a68 labeled as irregular_metal : 3
# 7a4045a8 labeled as irregular_metal : 3
# 7a404e0e labeled as irregular_metal : 3
# 7a4062f4 labeled as irregular_metal : 3
# 7a4066b4 labeled as irregular_metal : 3
# 7a407a64 labeled as irregular_metal : 3
# 7a407ce4 labeled as irregular_metal : 3
# 7a407d52 labeled as irregular_metal : 3
# 7a408c52 labeled as irregular_metal : 3
# 7a409648 labeled as irregular_metal : 3
# 7a409e9a labeled as irregular_metal : 3
# 7a40a2c8 labeled as irregular_metal : 3
# 7a40a5ac labeled as irregular_metal : 3
# 7a40ad5e labeled as irregular_metal : 3
# 7a40b9e8 labeled as irregular_metal : 3
# 7a40bb28 labeled as irregular_metal : 3
# 7a40c6c2 labeled as irregular_metal : 3
# 7a40c99c labeled as irregular_metal : 3
# 7a40d252 labeled as irregular_metal : 3
# 7a40d4c8 labeled as irregular_metal : 3
# 7a40d75c labeled as irregular_metal : 3
# 7a40e152 labeled as irregular_metal : 3
# 7a40e2f6 labeled as irregular_metal : 3
# 7a40eb3e labeled as irregular_metal : 3
# 7a40ef62 labeled as irregular_metal : 3
# 7a40f37c labeled as irregular_metal : 3
# 7a40f6c4 labeled as irregular_metal : 3
# 7a40f8d6 labeled as irregular_metal : 3
# 7a40fdcc labeled as irregular_metal : 3
# 7a40fe94 labeled as irregular_metal : 3
# 7a41061e labeled as irregular_metal : 3
# 7a410966 labeled as irregular_metal : 3
# 7a410c40 labeled as irregular_metal : 3
# 7a410d12 labeled as irregular_metal : 3
# 7a41147e labeled as irregular_metal : 3
# 7a4115b4 labeled as irregular_metal : 3
# 7a412018 labeled as irregular_metal : 3
# 7a412158 labeled as irregular_metal : 3
# 7a413530 labeled as irregular_metal : 3
# 7a4136de labeled as irregular_metal : 3
# 7a413f9e labeled as irregular_metal : 3
# 7a414b42 labeled as irregular_metal : 3
# 7a41509c labeled as irregular_metal : 3
# 7a41538a labeled as irregular_metal : 3
# 7a4157b8 labeled as irregular_metal : 3
# 7a415c5e labeled as irregular_metal : 3
# 7a415e7a labeled as irregular_metal : 3
# 7a415fce labeled as irregular_metal : 3
# 7a416884 labeled as irregular_metal : 3
# 7a416d70 labeled as irregular_metal : 3
# 7a4172de labeled as irregular_metal : 3
# 7a4173b0 labeled as irregular_metal : 3
# 7a417e00 labeled as irregular_metal : 3
# 7a4182b0 labeled as irregular_metal : 3
# 7a4186d4 labeled as irregular_metal : 3
# 7a418aee labeled as irregular_metal : 3
# 7a419200 labeled as irregular_metal : 3
# 7a4197c8 labeled as irregular_metal : 3
# 7a419908 labeled as irregular_metal : 3
# 7a419c50 labeled as irregular_metal : 3
# 7a419d2c labeled as irregular_metal : 3
# 7a41a984 labeled as irregular_metal : 3
# 7a41b672 labeled as irregular_metal : 3
# 7a41ba32 labeled as irregular_metal : 3
# 7a41c144 labeled as irregular_metal : 3
# 7a41c1b2 labeled as irregular_metal : 3
# 7a41c6c6 labeled as irregular_metal : 3
# 7a41d1e8 labeled as irregular_metal : 3
# 7a41d602 labeled as irregular_metal : 3
# 7a41d670 labeled as irregular_metal : 3
# 7a41de40 labeled as irregular_metal : 3
# 7a41e11a labeled as irregular_metal : 3
# 7a41e25a labeled as irregular_metal : 3
# 7a41f1f0 labeled as irregular_metal : 3
# 7a41f3f8 labeled as irregular_metal : 3
# 7a41fa1a labeled as irregular_metal : 3
# 7a420abe labeled as irregular_metal : 3
# 7a420c6c labeled as irregular_metal : 3
# 7a421414 labeled as irregular_metal : 3
# 7a421694 labeled as irregular_metal : 3
# 7a422cf6 labeled as irregular_metal : 3
# 7a422ff8 labeled as irregular_metal : 3
# 7a423138 labeled as irregular_metal : 3
# 7a42319c labeled as irregular_metal : 3
# 7a423412 labeled as irregular_metal : 3
# 7a423f02 labeled as irregular_metal : 3
# 7a424178 labeled as irregular_metal : 3
# 7a424394 labeled as irregular_metal : 3
# 7a424830 labeled as irregular_metal : 3
# 7a424e34 labeled as irregular_metal : 3
# 7a42550a labeled as irregular_metal : 3
# 7a426ffe labeled as irregular_metal : 3
# 7a42727e labeled as irregular_metal : 3
# 7a427c9c labeled as irregular_metal : 3
# 7a428494 labeled as irregular_metal : 3
# 7a429358 labeled as irregular_metal : 3
# 7a429434 labeled as irregular_metal : 3
# 7a4296b4 labeled as irregular_metal : 3
# 7a42a064 labeled as irregular_metal : 3
# 7a42a578 labeled as irregular_metal : 3
# 7a42a6c2 labeled as irregular_metal : 3
# 7a42af96 labeled as irregular_metal : 3
# 7a42b63a labeled as irregular_metal : 3
# 7a42b716 labeled as irregular_metal : 3
# 7a42bc20 labeled as irregular_metal : 3
# 7a42c198 labeled as irregular_metal : 3
# 7a42c2d8 labeled as irregular_metal : 3
# 7a42c5d0 labeled as irregular_metal : 3
# 7a42ceb8 labeled as irregular_metal : 3
# 7a42d214 labeled as irregular_metal : 3
# 7a42d570 labeled as irregular_metal : 3
# 7a42de3a labeled as irregular_metal : 3
# 7a42df0c labeled as irregular_metal : 3
# 7a42e0c4 labeled as irregular_metal : 3
# 7a42e772 labeled as irregular_metal : 3
# 7a42e98e labeled as irregular_metal : 3
# 7a42f0be labeled as irregular_metal : 3
# 7a42f2d0 labeled as irregular_metal : 3
# 7a42f76c labeled as irregular_metal : 3
# 7a42fc4e labeled as irregular_metal : 3
# 7a42ff96 labeled as irregular_metal : 3
# 7a430428 labeled as irregular_metal : 3
# 7a43070c labeled as irregular_metal : 3
# 7a430ce8 labeled as irregular_metal : 3
# 7a4311e8 labeled as irregular_metal : 3
# 7a43159e labeled as irregular_metal : 3
# 7a43195e labeled as irregular_metal : 3
# 7a431dfa labeled as irregular_metal : 3
# 7a4322a0 labeled as irregular_metal : 3
# 7a43280e labeled as irregular_metal : 3
# 7a432a20 labeled as irregular_metal : 3
# 7a432f16 labeled as irregular_metal : 3
# 7a43347a labeled as irregular_metal : 3
# 7a4334e8 labeled as irregular_metal : 3
# 7a43a2ac labeled as irregular_metal : 3
# 7a43a388 labeled as irregular_metal : 3
# 7a43a9c8 labeled as irregular_metal : 3
# 7a43c836 labeled as irregular_metal : 3
# 7a43cab6 labeled as irregular_metal : 3
# 7a43cd2c labeled as irregular_metal : 3
# 7a43d68c labeled as irregular_metal : 3
# 7a43d6fa labeled as irregular_metal : 3
# 7a43dcae labeled as irregular_metal : 3
# 7a43deb6 labeled as irregular_metal : 3
# 7a43df24 labeled as irregular_metal : 3
# 7a43e064 labeled as irregular_metal : 3
# 7a43e136 labeled as irregular_metal : 3
# 7a43e8fc labeled as irregular_metal : 3
# 7a43f892 labeled as irregular_metal : 3
# 7a43ffea labeled as irregular_metal : 3
# 7a440058 labeled as irregular_metal : 3
# 7a440d00 labeled as irregular_metal : 3
# 7a4414c6 labeled as irregular_metal : 3
# 7a441af2 labeled as irregular_metal : 3
# 7a441c32 labeled as irregular_metal : 3
# 7a441dcc labeled as irregular_metal : 3
# 7a442542 labeled as irregular_metal : 3
# 7a442678 labeled as irregular_metal : 3
# 7a4429c0 labeled as irregular_metal : 3
# 7a44312c labeled as irregular_metal : 3
# 7a4431fe labeled as irregular_metal : 3
# 7a443884 labeled as irregular_metal : 3
# 7a443a96 labeled as irregular_metal : 3
# 7a444040 labeled as irregular_metal : 3
# 7a444112 labeled as irregular_metal : 3
# 7a4443ec labeled as irregular_metal : 3
# 7a444c16 labeled as irregular_metal : 3
# 7a44556c labeled as irregular_metal : 3
# 7a445710 labeled as irregular_metal : 3
# 7a445f9e labeled as irregular_metal : 3
# 7a446688 labeled as irregular_metal : 3
# 7a4469da labeled as irregular_metal : 3
# 7a4475ec labeled as irregular_metal : 3
# 7a447fc4 labeled as irregular_metal : 3
# 7a4485e6 labeled as irregular_metal : 3
# 7a448d8e labeled as irregular_metal : 3
# 7a448f3c labeled as irregular_metal : 3
# 7a449158 labeled as irregular_metal : 3
# 7a44a5b2 labeled as irregular_metal : 3
# 7a44a8a0 labeled as irregular_metal : 3
# 7a44aa1c labeled as irregular_metal : 3
# 7a44afee labeled as irregular_metal : 3
# 7a44b20a labeled as irregular_metal : 3
# 7a44b62e labeled as irregular_metal : 3
# 7a44b69c labeled as irregular_metal : 3
# 7a44c9b6 labeled as irregular_metal : 3
# 7a1dc41a labeled as other : 4
# 7a1e6f46 labeled as other : 4
# 7a255400 labeled as other : 4
# 7a343d44 labeled as other : 4
# 7a391026 labeled as other : 4
# 7a3d7dfa labeled as other : 4
# 7a3dd502 labeled as other : 4
# 7a3f2984 labeled as other : 4

# %%
features_train.head()
# Out:
#          id                                           features label
# 0  7a1c6d7c  [0.8933228, 9.503732, 0.72881216, 3.7250175, 0...     0
# 1  7a1d078c  [0.0, 2.642926, 0.5762399, 0.0, 3.139349, 1.07...     0
# 2  7a1d2ff0  [1.8013268, 3.5478988, 2.0254405, 0.0, 0.78705...     0
# 3  7a1d570a  [4.6264086, 3.7589073, 8.721215, 0.4236287, 0....     0
# 4  7a1d6042  [1.9871483, 3.8774838, 6.796729, 0.10309696, 3...     0

# %%
import pickle
from os import makedirs
from os.path import exists

pickle_path = join('..', '..', 'pickles')
if not exists(pickle_path):
    makedirs(pickle_path)

with open(join(pickle_path, 'resnet50_features_' + region + '_train.pkl' ), 'wb') as f:
    pickle.dump(features_train, f)

# %% [markdown]
# ### Visualize the features
#
# Reduce the dimensionality to 2D using tSNE (https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
def plot_tSNE(features, labels=None, number_of_materials=5):
    if labels is None:
        labels = np.zeros((features.shape[0]))

    # Visualization_
    #pca_object = PCA(n_components=50)
    #pca_features = pca_object.fit_transform(features)
    tsne_features = TSNE(n_components=2).fit_transform(features)

    # define the colormap
    cmap = plt.cm.jet
    # extract all colors from the .jet map
    cmaplist = [cmap(i) for i in range(cmap.N)]
    # create the new map
    cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

    # define the bins and normalize
    bounds = np.linspace(0, number_of_materials, number_of_materials + 1)
    norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)
    
    print(tsne_features.shape)

    plt.figure()
    scat = plt.scatter(tsne_features[:, 0], tsne_features[:, 1], c=labels, cmap=cmap, norm=norm)
    cb = plt.colorbar(scat, spacing='proportional', ticks=bounds)

# %% [markdown]
# Convert features within the dataframe to a single matrix

# %%
feat_matrix = features_train['features'].to_numpy()
feat_matrix = np.column_stack(feat_matrix).transpose()

labels = features_train['label'].to_numpy()

# %%
plot_tSNE(feat_matrix, labels)

# %% [markdown]
# ## 2. Calculate features on the test data

# %% [markdown]
# This procedure is similar as for the training data, except that we do not know the labels and the folder with test images is not subdivided by material

# %%
def calculate_features_test(test_dir):
    
    # Initialize a dataframe for the features    
    columns = ['id', 'features']
    df_features = pd.DataFrame(columns=columns)

    # Walk through all images
    for root, dirs, files in os.walk(test_dir):
        for file in files:
            img_fp = join(root, file)
            id = file.split('.')[0]
            print("Calculate features for", id)

            # Pad if size is too small, preprocess
            img = image.load_img(img_fp, target_size=(224, 224))
            img_data = image.img_to_array(img)
            img_data = np.expand_dims(img_data, axis=0)
            img_data = preprocess_input(img_data)

            # Compute features 
            resnet50_feature = model.predict(img_data)
            resnet50_feature_np = np.array(resnet50_feature).flatten()

            df_features = df_features.append({'id': id ,
                                              'features': resnet50_feature_np},
                                             ignore_index=True)

    return df_features

# %%
features_test = calculate_features_test(test_dir)
# Out:
# Calculate features for 7a44e1d0
# Calculate features for 7a44e4c8
# Calculate features for 7a44e7b6
# Calculate features for 7a44e96e
# Calculate features for 7a44e9dc
# Calculate features for 7a44ecde
# Calculate features for 7a44f4c2
# Calculate features for 7a44f5f8
# Calculate features for 7a44f968
# Calculate features for 7a44fbd4
# Calculate features for 7a44fe4a
# Calculate features for 7a4506b0
# Calculate features for 7a450f8e
# Calculate features for 7a4516aa
# Calculate features for 7a4522ee
# Calculate features for 7a452708
# Calculate features for 7a45311c
# Calculate features for 7a4545f8
# Calculate features for 7a454de6
# Calculate features for 7a455be2
# Calculate features for 7a455f3e
# Calculate features for 7a455fac
# Calculate features for 7a456452
# Calculate features for 7a4572a8
# Calculate features for 7a45813a
# Calculate features for 7a458c98
# Calculate features for 7a4591ca
# Calculate features for 7a459ce2
# Calculate features for 7a459fee
# Calculate features for 7a45a78c
# Calculate features for 7a45a7fa
# Calculate features for 7a45ab6a
# Calculate features for 7a45b682
# Calculate features for 7a45b89e
# Calculate features for 7a45bd94
# Calculate features for 7a45d00e
# Calculate features for 7a45dcde
# Calculate features for 7a45e292
