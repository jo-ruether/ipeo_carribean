# %%
import rasterio
from rasterio.plot import show
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import json
from os.path import join

# %%
region = 'borde_soacha'

geojson_fp = join('..', '..', 'data', region, 'train-'+region+'.geojson')
image_fp = join('..', '..', 'data', region, region+'_ortho-cog.tif')
roof_dir = join('..', '..', 'data', region, 'roofs_train')

# %%
with rasterio.open(image_fp) as src:
    profile = src.profile
    print(profile['crs'])
    print(src.profile)
    print(src.bounds)
# Out:
# EPSG:32618
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 45650, 'height': 40159, 'count': 4, 'crs': CRS.from_epsg(32618), 'transform': Affine(0.04258000000000001, 0.0, 591256.29749,
#        0.0, -0.04258000000000001, 505836.91183000006), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'lzw', 'interleave': 'pixel'}
# BoundingBox(left=591256.29749, bottom=504126.94161000004, right=593200.07449, top=505836.91183000006)

# %% [markdown]
# ## 1. Get an overview of the scenery

# %%
with rasterio.open(image_fp) as src:
    oviews = src.overviews(1)
    oview = oviews[-1]
    print('Decimation factor = {}'.format(oview))
    thumbnail = src.read(1, out_shape=(1, int(src.height // oview), int(src.width // oview)))

plt.imshow(thumbnail)
plt.colorbar()
plt.title('Overview')
# Out:
# Decimation factor = 32
# Text(0.5, 1.0, 'Overview')

# %% [markdown]
# ## 2. Cut out roofs and store as separate files

# %%
import rasterio
from rasterio.mask import mask
from os import makedirs
from os.path import exists

# %% [markdown]
# Create subfolders for each material

# %%
materials = ['healthy_metal', 'irregular_metal', 'concrete_cement', 'incomplete', 'other']
for mat in materials:
    directory = join(roof_dir, mat) 
    if not exists(directory):
        makedirs(directory)

# %% [markdown]
# Coordinates in GeoJSON label file need to be converted to CSR format of the image

# %%
from pyproj import Proj, transform
outProj = Proj(init=profile['crs']) # CRS format of image
inProj = Proj(init='epsg:4326') # lat/lon coordinate format

# %% [markdown]
# #### Cutting out roofs
# 1. Extract the roof id and polygon coordinates from GeoJSON label file
# 2. Cut the polygon out of the image
# 3. Save the cut out image of the roof to file with id as name

# %%
with open(geojson_fp) as geojson:
    geoms = json.loads(geojson.read())
    roofs = geoms['features']

for roof in roofs:
    roof_id = roof['id']
    roof_geom = roof['geometry']
    roof_material = roof['properties']['roof_material']    
    
    print(roof_id)
    if roof_geom['type'] == 'MultiPolygon':
        print("MULTIPOLYGON")
        continue
    else:
        coord = roof_geom['coordinates'][0]
        for c in coord:
            c[0], c[1] = transform(inProj, outProj, c[0], c[1])
    
    print(roof_geom)
    with rasterio.open(image_fp) as image:
        roof_image, roof_transform = mask(image, [roof_geom], filled=True, crop=True)
    #show(roof_image)
    roof_meta = image.meta.copy()
    
    # save the resulting raster
    roof_meta.update({"driver": "GTiff",
        "dtype": rasterio.uint8,
        "height": roof_image.shape[1],
        "width": roof_image.shape[2],
        "transform": roof_transform,
        "tiled": True,
        "compress": 'lzw'})
    roof_image_fp = join(roof_dir, roof_material, str(roof_id)+".tif")

    with rasterio.open(roof_image_fp, "w", **roof_meta) as dest:
        dest.write(roof_image)
# Out:
# 7a407f5a
# {'type': 'Polygon', 'coordinates': [[[592000.7900085921, 505466.76545261964], [592002.7512538543, 505479.1097610238], [592005.5898529256, 505478.45203012426], [592005.3811640413, 505476.1564524005], [592011.1201083524, 505475.1130079794], [592011.5266918679, 505477.64246118243], [592014.7721638256, 505477.1998968238], [592012.810918565, 505464.8555884195], [592000.7900085921, 505466.76545261964]]]}
# 7a2d17b2
# {'type': 'Polygon', 'coordinates': [[[592013.1026527535, 505464.99159710493], [592014.3639340637, 505476.9737695473], [592017.1720859942, 505476.6781746095], [592015.9108046826, 505464.6960021612], [592013.1026527535, 505464.99159710493]]]}
# 7a2adccc
# {'type': 'Polygon', 'coordinates': [[[592028.8586635015, 505468.2262748091], [592035.7429296646, 505467.47330819623], [592035.0149855815, 505460.81781942025], [592028.1307194158, 505461.57078603294], [592028.8586635015, 505468.2262748091]]]}
# 7a346742
# {'type': 'Polygon', 'coordinates': [[[592030.8412078996, 505479.91285231337], [592040.0073415616, 505478.5888552312], [592039.1887632643, 505472.92177469644], [592030.022629599, 505474.2457717846], [592030.8412078996, 505479.91285231337]]]}
# 7a24a0fa
# {'type': 'Polygon', 'coordinates': [[[592032.0933412026, 505485.54745218356], [592044.3138057777, 505483.5629322956], [592043.4668853846, 505478.34768568346], [592031.2464208159, 505480.3322055712], [592032.0933412026, 505485.54745218356]]]}
# 7a367dfc
# {'type': 'Polygon', 'coordinates': [[[592001.4160752462, 505488.5734410042], [592005.5680928398, 505487.9001408534], [592005.0681307163, 505484.8170410914], [592000.9161131213, 505485.4903412406], [592001.4160752462, 505488.5734410042]]]}
# 7a32f2c2
# {'type': 'Polygon', 'coordinates': [[[592046.4928742063, 505496.71230748476], [592047.2501807826, 505502.66978588706], [592059.640273902, 505501.0947740489], [592058.8829673264, 505495.13729564456], [592046.4928742063, 505496.71230748476]]]}
# 7a262088
# {'type': 'Polygon', 'coordinates': [[[592036.6844966543, 505515.911684815], [592037.0636771526, 505521.6941874212], [592044.0929520378, 505521.23325136496], [592043.7137715408, 505515.45074875833], [592036.6844966543, 505515.911684815]]]}
# 7a41801c
# {'type': 'Polygon', 'coordinates': [[[591973.8691425478, 505514.0334848593], [591980.3384979521, 505512.67700711626], [591985.9730978226, 505511.8422515784], [591984.9296534027, 505506.72937391687], [591973.1387314532, 505509.1292960866], [591973.8691425478, 505514.0334848593]]]}
# 7a406132
# {'type': 'Polygon', 'coordinates': [[[592014.7454080397, 505532.42660455586], [592020.0551214974, 505531.7055323608], [592018.3834361511, 505519.3958493321], [592013.0737226919, 505520.1169215274], [592014.7454080397, 505532.42660455586]]]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-60dc1c95eb3b> in <module>
#      13         coord = roof_geom['coordinates'][0]
#      14         for c in coord:
# ---> 15             c[0], c[1] = transform(inProj, outProj, c[0], c[1])
#      16     print(roof_id)
#      17
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\pyproj\transformer.py in transform(p1, p2, x, y, z, tt, radians, errcheck, skip_equivalent, always_xy)
#     736     """
#     737     return Transformer.from_proj(
# --> 738         p1, p2, skip_equivalent=skip_equivalent, always_xy=always_xy
#     739     ).transform(xx=x, yy=y, zz=z, tt=tt, radians=radians, errcheck=errcheck)
#     740
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\pyproj\transformer.py in from_proj(proj_from, proj_to, skip_equivalent, always_xy, area_of_interest)
#     260             skip_equivalent=skip_equivalent,
#     261             always_xy=always_xy,
# --> 262             area_of_interest=area_of_interest,
#     263         )
#     264
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\pyproj\transformer.py in from_crs(crs_from, crs_to, skip_equivalent, always_xy, area_of_interest)
#     301                 skip_equivalent=skip_equivalent,
#     302                 always_xy=always_xy,
# --> 303                 area_of_interest=area_of_interest,
#     304             )
#     305         )
#
# pyproj/_transformer.pyx in pyproj._transformer._Transformer.from_crs()
#
# pyproj/_transformer.pyx in pyproj._transformer._Transformer._init_from_crs()
#
# pyproj/_transformer.pyx in pyproj._transformer._Transformer._initialize_from_projobj()
#
# pyproj/_crs.pyx in pyproj._crs.Base._set_base_info()
#
# pyproj/_crs.pyx in pyproj._crs.decode_or_undefined()
#
# pyproj/_crs.pyx in pyproj._crs.cstrdecode()
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\pyproj\compat.py in pystrdecode(cstr)
#      18     Decode a string to a python string.
#      19     """
# ---> 20     try:
#      21         return cstr.decode("utf-8")
#      22     except AttributeError:
#
# KeyboardInterrupt:

# %% [markdown]
# All this can also happen using the module `preprocessing`

# %%
import preprocessing

# %%
region = 'borde_soacha'
preprocessing.preprocess_region(region)
# Out:
# 7a407f5a
# 7a29f6b8
# 7a3f90f4
# 7a3fe086
# 7a43babc
# 7a386716
# 7a30c2ea
# 7a277988
# 7a1e7d42
# 7a22b2fe
# 7a2d9d7c
# 7a391c2e
# 7a1c7c04
# 7a25069e
# 7a2abff8
# 7a2dd6ca
# 7a363bb2
# 7a352dd0
# 7a1eab64
# 7a3ca8d0
# 7a354aa4
# 7a28c716
# 7a3138b0
# 7a2dff24
# 7a3691de
# 7a380172
# 7a210bb6
# 7a1dc2ee
# 7a226808
# 7a25bb2a
# 7a3183ba
# 7a2499b6
# 7a1e4bb0
# 7a226ae2
# 7a4264a0
# 7a2bcb8c
# 7a21be76
# 7a2d17b2
# 7a2adccc
# 7a346742
# 7a24a0fa
# 7a367dfc
# 7a32f2c2
# 7a262088
# 7a41801c
# 7a406132
# 7a222f46
# 7a2b89b0
# 7a43c69c
# 7a28496c
# 7a335906
# 7a3e93ca
# 7a43d0d8
# 7a2f0e50
# 7a237496
# 7a24652c
# 7a41abfa
# 7a356d68
# 7a4095e4
# 7a2f2796
# 7a231bf4
# 7a21e4dc
# 7a36ffde
# 7a412fe0
# 7a39a054
# 7a3e950a
# 7a1ec9be
# 7a356110
# 7a36302c
# 7a3802c6
# 7a2a35ec
# 7a3872a6
# 7a3e91b8
# 7a362b0e
# 7a32e412
# 7a1d0b88
# 7a25cd54
# 7a42ea06
# 7a223f36
# 7a390a5e
# 7a36797e
# 7a34563a
# 7a4154ca
# 7a1ec3ec
# 7a29d980
# 7a209b68
# 7a1e2252
# 7a2265f6
# 7a40b2e0
# 7a22ef9e
# 7a1d6c22
# 7a32e5b6
# 7a3fad28
# 7a4490ea
# 7a27b34e
# 7a225d72
# 7a369e5e
# 7a1dfa98
# 7a3771e4
# 7a1f901a
# 7a40db12
# 7a222cd0
# 7a1ef768
# 7a323b0c
# 7a3279fa
# 7a212920
# 7a233440
# 7a241afe
# 7a2e12a2
# 7a3cedea
# 7a1d5b10
# 7a29c800
# 7a25aaea
# 7a2cbe20
# 7a444590
# 7a2e5c8a
# 7a3c04c0
# 7a26eefa
# 7a277d0c
# 7a41e67e
# 7a33fe9c
# 7a3379b8
# 7a1e1028
# 7a281834
# 7a2fd63c
# 7a1fc594
# 7a1d91a2
# 7a2ff2a2
# 7a3413d2
# 7a3c270c
# 7a26b7dc
# 7a3c6582
# 7a21bbb0
# 7a293e76
# 7a2bee14
# 7a2fc192
# 7a1fa4ec
# 7a21de06
# 7a24460a
# 7a2e631a
# 7a1f6f72
# 7a3d6b26
# 7a231b0e
# 7a392a66
# 7a3da71c
# 7a2d5c0e
# 7a3adffa
# 7a3e098c
# 7a42490c
# 7a20faae
# 7a37c068
# 7a1ef204
# 7a20e76c
# 7a4146b0
# 7a204988
# 7a1d4cba
# 7a320c0e
# 7a26c7cc
# 7a30e73e
# 7a2e0ee2
# 7a35130e
# 7a233134
# 7a32d7ce
# 7a2e4cea
# ---------------------------------------------------------------------------
# WindowError                               Traceback (most recent call last)
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\mask.py in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      83         window = geometry_window(dataset, shapes, north_up=north_up, rotated=rotated,
# ---> 84                                  pad_x=pad_x, pad_y=pad_y)
#      85
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\features.py in geometry_window(dataset, shapes, pad_x, pad_y, north_up, rotated, pixel_precision)
#     455     # This will raise a WindowError if windows do not overlap
# --> 456     window = window.intersection(raster_window)
#     457
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\windows.py in intersection(self, other)
#     714         """
# --> 715         return intersection([self, other])
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\windows.py in wrapper(*args, **kwargs)
#     118         if len(args) == 1 and isinstance(args[0], Iterable):
# --> 119             return function(*args[0])
#     120         else:
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\windows.py in intersection(*windows)
#     216     if not intersect(windows):
# --> 217         raise WindowError("windows do not intersect")
#     218
#
# WindowError: windows do not intersect
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f02620fe0fe3> in <module>
#       1 region = 'borde_soacha'
# ----> 2 preprocessing.preprocess_region(region)
#
# ~\Documents\Elektrotechnik\EPFL\IPEO\Final project\ipeo_carribean\src\preprocessing.py in preprocess_region(region)
#     141
#     142     preprocess_training(geojson_train, image_fp,
# --> 143                         profile, roofs_train_dir)
#     144
#     145     preprocess_test(geojson_test, image_fp,
#
# ~\Documents\Elektrotechnik\EPFL\IPEO\Final project\ipeo_carribean\src\preprocessing.py in preprocess_training(geojson_train, image_fp, profile, roofs_train_dir)
#      44         with rasterio.open(image_fp) as image:
#      45             roof_image, roof_transform = mask(image, [roof_geom],
# ---> 46                                              filled=True, crop=True)
#      47         roof_meta = image.meta.copy()
#      48         roof_meta.update({"driver": "GTiff",
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\mask.py in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     182     shape_mask, transform, window = raster_geometry_mask(
#     183         dataset, shapes, all_touched=all_touched, invert=invert, crop=crop,
# --> 184         pad=pad, pad_width=pad_width)
#     185
#     186     if indexes is None:
#
# ~\Miniconda3\envs\ipeo\lib\site-packages\rasterio\mask.py in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      88         # depending on value of crop
#      89         if crop:
# ---> 90             raise ValueError('Input shapes do not overlap raster.')
#      91         else:
#      92             warnings.warn('shapes are outside bounds of raster. '
#
# ValueError: Input shapes do not overlap raster.

# %%
preprocessing.greetings()
